# %% [markdown]
# # Gender name data prediction

# %%
# library imports
import pickle
import pandas as pd
import os.path as path

# Library imports
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn. model_selection import train_test_split
from tensorflow.keras.layers import Dense, Input, Conv1D, Flatten, MaxPool2D, BatchNormalization, Dropout, LSTM, Embedding, Masking
from tensorflow.keras.models import Model
from tensorflow.keras import activations

from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Data import

# %%
# Importing data
parent = path.abspath(path.join("03_gender_name_prediction.ipynb" ,"../.."))

with open(f'{parent}/processed/all_gender_name.obj', 'rb') as f:
	data = pickle.load(f)

# %%
X = data[0]
y = data[1]

# %%
chars = []
for name in X:
    for char in name:
        chars.append(char.lower())
chars = list(set(chars))

# %% [markdown]
# ### ML data prep

# %%
# Tokenization of characters.

list_of_unique_char = []
for name in X:
    for char in name:
        list_of_unique_char.append(char.lower())
list_of_unique_char = list(set(list_of_unique_char))
print(len(list_of_unique_char))
# Out:
# 38

# %%
# Create a character dictionary
char_dictionary = {}
count = 0
for char in list_of_unique_char:
    char_dictionary[char] = count
    count += 1

# %%
X_token = []

for name in X:
    name_unit = []
    for char in name:
        all_chars = [0 for x in range(len(list_of_unique_char))]
        all_chars[char_dictionary[char.lower()]] = 1
        name_unit.append(all_chars)
    X_token.append(name_unit)

# %%
y_encoded = []
for gender in y:
    if gender == "M":
        y_encoded.append([1,0])
    else:
        y_encoded.append([0,1])
y = y_encoded

# %%
y = np.array(y)
X_token = pad_sequences(X_token, padding='post', value=0, maxlen=20)
print(y.shape)
#X_token = X_token.reshape(-1, 16, 38, 1)
X = X_token
print(X.shape)
# Out:
# (96756, 2)
# (96756, 20, 38)

# %%
# Split into test and train
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.001)

print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print("")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of X_train: (96659, 20, 38)
# Shape of X_test: (97, 20, 38)
#
# Shape of y_train: (96659, 2)
# Shape of y_test: (97, 2)

# %% [markdown]
# # The machinelearning model
# A LSTM model is used.

# %%
input_layer = Input(shape=(20,38))
conv_layer_1 = Conv1D(38,2,padding='same', use_bias=False)(input_layer)
masked_input = Masking(mask_value = 0)(conv_layer_1)
print(masked_input.shape)
print(masked_input._keras_mask.shape)
lstm_layer_1= LSTM(38*6)(masked_input)
print(lstm_layer_1.shape)
output_layer = Dense(2, activation = 'softmax')(lstm_layer_1)
# Out:
# (None, 20, 38)
# (None, 20)
# (None, 228)

# %%
# Model setup
gender_name_model = Model(inputs=input_layer, outputs=output_layer)
gender_name_model.compile(optimizer='adam', 
                    loss='categorical_crossentropy',
                    metrics='accuracy')

# %%
gender_name_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20, 38)]          0
#
#  conv1d (Conv1D)             (None, 20, 38)            2888
#
#  masking (Masking)           (None, 20, 38)            0
#
#  lstm (LSTM)                 (None, 228)               243504
#
#  dense (Dense)               (None, 2)                 458
#
# =================================================================
# Total params: 246,850
# Trainable params: 246,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model fit
history_0=gender_name_model.fit(X_train, 
                                y_train, 
                                validation_data=[X_test, y_test], 
                                batch_size=128, 
                                epochs=15)
# Out:
# Epoch 1/15
# 756/756 [==============================] - 62s 78ms/step - loss: 0.3924 - accuracy: 0.8212 - val_loss: 0.4073 - val_accuracy: 0.8144
# Epoch 2/15
# 756/756 [==============================] - 52s 69ms/step - loss: 0.3403 - accuracy: 0.8510 - val_loss: 0.3281 - val_accuracy: 0.8660
# Epoch 3/15
# 756/756 [==============================] - 51s 67ms/step - loss: 0.3092 - accuracy: 0.8659 - val_loss: 0.2970 - val_accuracy: 0.8660
# Epoch 4/15
# 756/756 [==============================] - 53s 70ms/step - loss: 0.2869 - accuracy: 0.8769 - val_loss: 0.3028 - val_accuracy: 0.8763
# Epoch 5/15
# 756/756 [==============================] - 51s 67ms/step - loss: 0.2672 - accuracy: 0.8857 - val_loss: 0.2731 - val_accuracy: 0.8969
# Epoch 6/15
# 756/756 [==============================] - 51s 67ms/step - loss: 0.2487 - accuracy: 0.8940 - val_loss: 0.2956 - val_accuracy: 0.9072
# Epoch 7/15
# 756/756 [==============================] - 51s 68ms/step - loss: 0.2319 - accuracy: 0.9029 - val_loss: 0.2720 - val_accuracy: 0.8763
# Epoch 8/15
# 756/756 [==============================] - 51s 67ms/step - loss: 0.2134 - accuracy: 0.9104 - val_loss: 0.2642 - val_accuracy: 0.8866
# Epoch 9/15
# 756/756 [==============================] - 52s 69ms/step - loss: 0.1953 - accuracy: 0.9185 - val_loss: 0.2880 - val_accuracy: 0.8969
# Epoch 10/15
# 756/756 [==============================] - 52s 68ms/step - loss: 0.1769 - accuracy: 0.9274 - val_loss: 0.2920 - val_accuracy: 0.8763
# Epoch 11/15
# 756/756 [==============================] - 51s 68ms/step - loss: 0.1592 - accuracy: 0.9354 - val_loss: 0.2791 - val_accuracy: 0.8969
# Epoch 12/15
# 756/756 [==============================] - 52s 68ms/step - loss: 0.1412 - accuracy: 0.9429 - val_loss: 0.2890 - val_accuracy: 0.8969
# Epoch 13/15
# 756/756 [==============================] - 52s 68ms/step - loss: 0.1228 - accuracy: 0.9509 - val_loss: 0.3519 - val_accuracy: 0.8866
# Epoch 14/15
# 756/756 [==============================] - 52s 69ms/step - loss: 0.1051 - accuracy: 0.9580 - val_loss: 0.2926 - val_accuracy: 0.9175
# Epoch 15/15
# 756/756 [==============================] - 51s 68ms/step - loss: 0.0888 - accuracy: 0.9657 - val_loss: 0.2709 - val_accuracy: 0.8969

# %% [markdown]
# ## Import name data

# %%
# Data import
parent = path.abspath(path.join("03_gender_name_prediction.ipynb" ,"../../.."))
with open(f'{parent}/Data/Extracted/df_people.obj', 'rb') as file:
	people_data = pickle.load(file)

# %%
def first_name_extractor(name):
    first_name = ""
    for char in name:
        if char == " ":
            return first_name
        else:
            first_name = first_name + char


people_data['first_name'] = people_data['navn'].map(first_name_extractor)

# %%
first_name_list = people_data['first_name'].tolist()

# %%
first_name_list[0]
# Out:
# 'Fredrik'

# %%
name_token = []

for name in first_name_list:
    name_unit = []
    for char in name:
        all_chars = [0 for x in range(len(list_of_unique_char))]
        all_chars[char_dictionary[char.lower()]] = 1
        name_unit.append(all_chars)
    name_token.append(name_unit)

# %%
name_token = pad_sequences(name_token, padding='post', value=0, maxlen=20)
print(name_token.shape)
# Out:
# (1853, 20, 38)

# %%
predictions = gender_name_model.predict(name_token)
# Out:
# 58/58 [==============================] - 0s 8ms/step

# %%
for name, prediction in zip(first_name_list, predictions):
    print(f"The name is: {name} and the prediction is: {prediction}")
# Out:
# The name is: Fredrik and the prediction is: [9.9996066e-01 3.9306058e-05]
# The name is: Fredrik and the prediction is: [9.9996066e-01 3.9306058e-05]
# The name is: Stian and the prediction is: [0.960796   0.03920402]
# The name is: Even and the prediction is: [0.8739496  0.12605041]
# The name is: Mohammad and the prediction is: [9.996014e-01 3.985437e-04]
# The name is: Thomas and the prediction is: [0.07485382 0.9251462 ]
# The name is: Lydia and the prediction is: [5.9567086e-05 9.9994040e-01]
# The name is: Karl and the prediction is: [0.99283594 0.00716403]
# The name is: Sven-Helge and the prediction is: [0.55874085 0.44125912]
# The name is: Gyrid and the prediction is: [9.994228e-01 5.772059e-04]
# The name is: Mustfa and the prediction is: [0.06921294 0.9307871 ]
# The name is: Brian and the prediction is: [0.9727946  0.02720537]
# The name is: Firat and the prediction is: [0.12715147 0.8728486 ]
# The name is: Arnt and the prediction is: [9.9955970e-01 4.4023848e-04]
# The name is: Anna and the prediction is: [1.3141868e-04 9.9986851e-01]
# The name is: Axel and the prediction is: [0.982488   0.01751208]
# The name is: Erik and the prediction is: [0.9977958 0.0022042]
# The name is: Anjum and the prediction is: [0.6215181 0.378482 ]
# The name is: Jaime and the prediction is: [0.82653654 0.17346346]
# The name is: Hestiar and the prediction is: [0.8190002  0.18099982]
# The name is: Jan and the prediction is: [0.94735533 0.05264461]
# The name is: Anna and the prediction is: [1.3141868e-04 9.9986851e-01]
# The name is: Kari and the prediction is: [0.45040607 0.5495939 ]
# The name is: Thorbjørn and the prediction is: [0.99791056 0.00208945]
# The name is: Susanne and the prediction is: [2.4099554e-05 9.9997592e-01]
# The name is: Zahid and the prediction is: [0.98132646 0.01867351]
# The name is: Kim and the prediction is: [0.7929864  0.20701367]
# The name is: Qimei and the prediction is: [0.08979765 0.9102024 ]
# The name is: Timon and the prediction is: [0.9980171  0.00198293]
# The name is: Laura and the prediction is: [0.0315968 0.9684032]
# The name is: Mushtaq and the prediction is: [0.0260272  0.97397286]
# The name is: Henry and the prediction is: [0.9448369  0.05516306]
# The name is: Rudolf and the prediction is: [9.9908900e-01 9.1101695e-04]
# The name is: Kristian and the prediction is: [0.9445449  0.05545508]
# The name is: Veslemøy and the prediction is: [4.2511115e-07 9.9999952e-01]
# The name is: Trond and the prediction is: [9.9952483e-01 4.7513930e-04]
# The name is: Noman and the prediction is: [0.93205804 0.06794201]
# The name is: Trond and the prediction is: [9.9952483e-01 4.7513930e-04]
# The name is: Bhupinder and the prediction is: [0.05655297 0.943447  ]
# The name is: Robert and the prediction is: [0.99268734 0.00731267]
# The name is: Julian and the prediction is: [9.990509e-01 9.490326e-04]
# The name is: Einar and the prediction is: [0.9699388  0.03006123]
# The name is: Lars and the prediction is: [9.9927467e-01 7.2531495e-04]
# The name is: Marianne and the prediction is: [1.5465649e-07 9.9999988e-01]
# The name is: Anneli and the prediction is: [2.184406e-05 9.999782e-01]
# The name is: Khiem and the prediction is: [9.999398e-01 6.023588e-05]
# The name is: Benjamin and the prediction is: [9.9999988e-01 6.2473944e-08]
# The name is: Hassan and the prediction is: [9.999733e-01 2.666004e-05]
# The name is: Meheret and the prediction is: [0.3040098  0.69599015]
# The name is: Therese and the prediction is: [0.00223944 0.99776053]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Fanny and the prediction is: [0.16692102 0.833079  ]
# The name is: Ian and the prediction is: [0.9871133  0.01288669]
# The name is: Stein and the prediction is: [0.99771    0.00228997]
# The name is: Rebecca and the prediction is: [1.8228752e-04 9.9981779e-01]
# The name is: Helen and the prediction is: [0.00169544 0.9983045 ]
# The name is: Frank and the prediction is: [0.5071813 0.4928187]
# The name is: Christian and the prediction is: [0.9952348  0.00476517]
# The name is: Susanne and the prediction is: [2.4099554e-05 9.9997592e-01]
# The name is: Baljit and the prediction is: [0.9987789  0.00122111]
# The name is: Fredrik and the prediction is: [9.9996066e-01 3.9306058e-05]
# The name is: Jan and the prediction is: [0.94735533 0.05264461]
# The name is: Ann and the prediction is: [0.0190923  0.98090774]
# The name is: Vincenzo and the prediction is: [9.9999976e-01 2.7313817e-07]
# The name is: Dimitar and the prediction is: [0.9974189  0.00258114]
# The name is: Tor and the prediction is: [0.9480622  0.05193776]
# The name is: Cuiming and the prediction is: [9.992494e-01 7.505284e-04]
# The name is: Bjørg and the prediction is: [0.98385644 0.01614352]
# The name is: Dag and the prediction is: [0.9888609  0.01113912]
# The name is: Tsion and the prediction is: [0.8682264  0.13177364]
# The name is: Dan and the prediction is: [0.96981376 0.03018622]
# The name is: Michelle and the prediction is: [5.6034096e-06 9.9999440e-01]
# The name is: Ann and the prediction is: [0.0190923  0.98090774]
# The name is: Michael and the prediction is: [9.9965692e-01 3.4308634e-04]
# The name is: Khabi and the prediction is: [0.93249774 0.06750222]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Mukhtar and the prediction is: [0.9597678  0.04023218]
# The name is: Muhammad and the prediction is: [9.9997902e-01 2.0992024e-05]
# The name is: Shiva and the prediction is: [0.0034609 0.9965391]
# The name is: Mai and the prediction is: [0.02279825 0.9772018 ]
# The name is: Andreas and the prediction is: [9.9973243e-01 2.6758359e-04]
# The name is: Mohammad and the prediction is: [9.996014e-01 3.985437e-04]
# The name is: Ingun and the prediction is: [0.07089252 0.92910755]
# The name is: Tore and the prediction is: [0.95754695 0.04245313]
# The name is: Yubao and the prediction is: [0.5803838  0.41961622]
# The name is: Harry and the prediction is: [0.7892446  0.21075542]
# The name is: Jan and the prediction is: [0.94735533 0.05264461]
# The name is: Runar and the prediction is: [0.9729393  0.02706066]
# The name is: Karamjit and the prediction is: [0.994743   0.00525701]
# The name is: Zlatoslav and the prediction is: [9.9999976e-01 1.8280583e-07]
# The name is: Tikaram and the prediction is: [0.85016114 0.14983886]
# The name is: Bandit and the prediction is: [0.18717465 0.8128254 ]
# The name is: Sharda and the prediction is: [0.00614461 0.9938554 ]
# The name is: Mikael and the prediction is: [9.9986744e-01 1.3249450e-04]
# The name is: Yennie and the prediction is: [0.03087313 0.9691269 ]
# The name is: Jan and the prediction is: [0.94735533 0.05264461]
# The name is: Daniel and the prediction is: [0.9933357 0.0066643]
# The name is: Nicolai and the prediction is: [9.9991655e-01 8.3437379e-05]
# The name is: Sverre and the prediction is: [0.9101686  0.08983136]
# The name is: Berivan and the prediction is: [0.98597705 0.01402297]
# The name is: Camilla and the prediction is: [1.9838882e-07 9.9999976e-01]
# The name is: Trine and the prediction is: [0.03080754 0.96919245]
# The name is: Aksel and the prediction is: [0.987258   0.01274198]
# The name is: Marius and the prediction is: [0.8736751  0.12632492]
# The name is: Erik and the prediction is: [0.9977958 0.0022042]
# The name is: Parag and the prediction is: [0.9769882 0.0230118]
# The name is: Noora and the prediction is: [0.03738929 0.96261066]
# The name is: Björn and the prediction is: [9.999976e-01 2.422697e-06]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Jenny and the prediction is: [0.07736114 0.9226388 ]
# The name is: Håkon and the prediction is: [0.9784107  0.02158928]
# The name is: Håvard and the prediction is: [9.9999845e-01 1.5570561e-06]
# The name is: Claus and the prediction is: [0.9963012  0.00369878]
# The name is: Ann and the prediction is: [0.0190923  0.98090774]
# The name is: Hafiz and the prediction is: [9.9985182e-01 1.4817648e-04]
# The name is: Torgeir and the prediction is: [0.9926152  0.00738484]
# The name is: Silje and the prediction is: [0.06934792 0.930652  ]
# The name is: Pål and the prediction is: [0.9776963  0.02230366]
# The name is: Bård and the prediction is: [0.9910876  0.00891241]
# The name is: Lene and the prediction is: [9.6975290e-04 9.9903023e-01]
# The name is: Magnus and the prediction is: [0.97110873 0.02889123]
# The name is: Axel and the prediction is: [0.982488   0.01751208]
# The name is: Line and the prediction is: [0.00570607 0.99429387]
# The name is: Mai and the prediction is: [0.02279825 0.9772018 ]
# The name is: Cong and the prediction is: [0.86576736 0.13423261]
# The name is: Bjørn-Erik and the prediction is: [0.9928134  0.00718659]
# The name is: Mia and the prediction is: [0.01000866 0.9899913 ]
# The name is: Hans and the prediction is: [0.9984994  0.00150065]
# The name is: Fahmi and the prediction is: [0.5887002  0.41129988]
# The name is: Victor and the prediction is: [9.9983633e-01 1.6368026e-04]
# The name is: Bjørn and the prediction is: [9.9995804e-01 4.1953888e-05]
# The name is: Jojo and the prediction is: [0.04631047 0.9536895 ]
# The name is: Finn and the prediction is: [0.8758559  0.12414415]
# The name is: Lisa and the prediction is: [4.1940046e-05 9.9995804e-01]
# The name is: Sylvia and the prediction is: [8.3973966e-08 9.9999988e-01]
# The name is: Tuong and the prediction is: [0.7532879  0.24671209]
# The name is: Suphattra and the prediction is: [1.0011681e-07 9.9999988e-01]
# The name is: Jørgen and the prediction is: [0.9976757  0.00232426]
# The name is: Harald and the prediction is: [9.9997604e-01 2.4001620e-05]
# The name is: Astrid and the prediction is: [0.01715784 0.98284215]
# The name is: Thi and the prediction is: [0.8061922  0.19380781]
# The name is: Jan and the prediction is: [0.94735533 0.05264461]
# The name is: Milan and the prediction is: [0.7632864  0.23671356]
# The name is: Yat and the prediction is: [0.963104 0.036896]
# The name is: Weijiang and the prediction is: [0.9537274  0.04627258]
# The name is: Paulina and the prediction is: [2.5257628e-05 9.9997473e-01]
# The name is: Loay and the prediction is: [0.9487926  0.05120739]
# The name is: Aras and the prediction is: [0.98229975 0.01770022]
# The name is: Ulrik and the prediction is: [0.99819154 0.00180847]
# The name is: Timothy and the prediction is: [9.9998188e-01 1.8123492e-05]
# The name is: Abdallah and the prediction is: [9.9999785e-01 2.1667333e-06]
# The name is: Mohsen and the prediction is: [9.9991322e-01 8.6752916e-05]
# The name is: Olav and the prediction is: [0.98675483 0.01324518]
# The name is: Lise and the prediction is: [0.03839187 0.9616082 ]
# The name is: Jahn and the prediction is: [0.8692838  0.13071622]
# The name is: Kim and the prediction is: [0.7929864  0.20701367]
# The name is: Michael and the prediction is: [9.9965692e-01 3.4308634e-04]
# The name is: Isabella and the prediction is: [7.4375305e-07 9.9999928e-01]
# The name is: Richard and the prediction is: [9.9971873e-01 2.8120173e-04]
# The name is: Kaveh and the prediction is: [0.9398373  0.06016269]
# The name is: Ioannis and the prediction is: [9.9988747e-01 1.1251721e-04]
# The name is: Oda and the prediction is: [0.015015 0.984985]
# The name is: Liss-Hege and the prediction is: [0.01127093 0.9887291 ]
# The name is: Rona and the prediction is: [1.2937238e-04 9.9987066e-01]
# The name is: Geir and the prediction is: [0.98203665 0.01796332]
# The name is: Ashiq and the prediction is: [9.9982846e-01 1.7153997e-04]
# The name is: Eyüp and the prediction is: [0.9848369  0.01516311]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Mohammad and the prediction is: [9.996014e-01 3.985437e-04]
# The name is: Charles and the prediction is: [0.9742309  0.02576914]
# The name is: Karl and the prediction is: [0.99283594 0.00716403]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Buday and the prediction is: [0.9947672  0.00523286]
# The name is: Bjørne and the prediction is: [0.03334657 0.96665347]
# The name is: Bengt and the prediction is: [0.92944777 0.07055221]
# The name is: Israr and the prediction is: [0.97274935 0.02725068]
# The name is: Erlend and the prediction is: [0.92011094 0.07988904]
# The name is: Christopher and the prediction is: [9.9999285e-01 7.1397558e-06]
# The name is: Kjersti and the prediction is: [5.8713584e-05 9.9994123e-01]
# The name is: Ellen and the prediction is: [0.01560154 0.9843985 ]
# The name is: Ole and the prediction is: [0.29307315 0.7069268 ]
# The name is: Kutlay and the prediction is: [0.92627555 0.07372441]
# The name is: Liam and the prediction is: [0.8614913  0.13850868]
# The name is: Tom and the prediction is: [0.8946094  0.10539059]
# The name is: Linda and the prediction is: [1.4244340e-04 9.9985754e-01]
# The name is: Reza and the prediction is: [0.44558302 0.554417  ]
# The name is: Emil and the prediction is: [0.96702486 0.03297518]
# The name is: Prakash and the prediction is: [9.9987090e-01 1.2907357e-04]
# The name is: Stein and the prediction is: [0.99771    0.00228997]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Hanne and the prediction is: [0.00487212 0.9951279 ]
# The name is: Jose and the prediction is: [0.60681754 0.39318252]
# The name is: Sondre and the prediction is: [0.7994846 0.2005154]
# The name is: Suradeth and the prediction is: [0.0079448 0.9920551]
# The name is: Sarah and the prediction is: [3.608521e-05 9.999639e-01]
# The name is: Hoang and the prediction is: [0.9894705  0.01052954]
# The name is: Omar and the prediction is: [0.9912152  0.00878476]
# The name is: Sofian and the prediction is: [0.998613   0.00138695]
# The name is: Omar and the prediction is: [0.9912152  0.00878476]
# The name is: Tobias and the prediction is: [0.9935183  0.00648171]
# The name is: Andrea and the prediction is: [4.6779383e-05 9.9995327e-01]
# The name is: Kristel and the prediction is: [1.49795815e-05 9.99984980e-01]
# The name is: Maren and the prediction is: [0.00902885 0.9909711 ]
# The name is: Eva and the prediction is: [0.00113123 0.99886876]
# The name is: Hans and the prediction is: [0.9984994  0.00150065]
# The name is: Kitty and the prediction is: [0.10837049 0.89162946]
# The name is: Alexander and the prediction is: [9.999994e-01 5.865879e-07]
# The name is: Batoul and the prediction is: [0.01140771 0.9885923 ]
# The name is: Abdelkarim and the prediction is: [9.9999475e-01 5.2358610e-06]
# The name is: Rupinder and the prediction is: [0.31882966 0.68117034]
# The name is: Kiran and the prediction is: [0.17555204 0.824448  ]
# The name is: Marit and the prediction is: [0.07400985 0.92599016]
# The name is: Terje and the prediction is: [0.97790843 0.0220916 ]
# The name is: Airis and the prediction is: [0.21932183 0.78067815]
# The name is: Aslak and the prediction is: [0.9539751  0.04602494]
# The name is: Rebecca and the prediction is: [1.8228752e-04 9.9981779e-01]
# The name is: Mubasshar and the prediction is: [9.9999976e-01 2.5364494e-07]
# The name is: Ole and the prediction is: [0.29307315 0.7069268 ]
# The name is: Rizwan and the prediction is: [0.98474276 0.01525721]
# The name is: Eddy and the prediction is: [0.91902333 0.08097662]
# The name is: Lena and the prediction is: [2.7765825e-08 1.0000000e+00]
# The name is: Eva and the prediction is: [0.00113123 0.99886876]
# The name is: Grethe and the prediction is: [0.1114293 0.8885707]
# The name is: Lars and the prediction is: [9.9927467e-01 7.2531495e-04]
# The name is: Jihong and the prediction is: [0.8932774  0.10672267]
# The name is: Simen and the prediction is: [0.38362482 0.6163752 ]
# The name is: Erk and the prediction is: [9.9976057e-01 2.3938082e-04]
# The name is: Tommy and the prediction is: [0.94638747 0.05361256]
# The name is: Kine and the prediction is: [0.7215082 0.2784918]
# The name is: Knut and the prediction is: [0.95275253 0.04724744]
# The name is: Jens and the prediction is: [0.9853668  0.01463315]
# The name is: Sagar and the prediction is: [0.7169808 0.2830192]
# The name is: Hilje and the prediction is: [0.9619054  0.03809452]
# The name is: Lars and the prediction is: [9.9927467e-01 7.2531495e-04]
# The name is: Jawad and the prediction is: [0.9845077  0.01549229]
# The name is: Hanne and the prediction is: [0.00487212 0.9951279 ]
# The name is: Chirag and the prediction is: [0.9554974  0.04450253]
# The name is: Raden and the prediction is: [0.9940234 0.0059766]
# The name is: Roar and the prediction is: [0.9794967  0.02050326]
# The name is: Mark and the prediction is: [0.98734206 0.01265792]
# The name is: Ole and the prediction is: [0.29307315 0.7069268 ]
# The name is: Unni and the prediction is: [0.2470128 0.7529872]
# The name is: David and the prediction is: [9.999751e-01 2.492560e-05]
# The name is: Birgitte and the prediction is: [1.8405801e-05 9.9998164e-01]
# The name is: Helge and the prediction is: [0.70374614 0.2962539 ]
# The name is: Kushtrim and the prediction is: [0.9741576 0.0258424]
# The name is: Tarsem and the prediction is: [0.32154435 0.6784557 ]
# The name is: Knut and the prediction is: [0.95275253 0.04724744]
# The name is: Prince and the prediction is: [0.987953   0.01204697]
# The name is: Mette and the prediction is: [0.0835097  0.91649026]
# The name is: Lars and the prediction is: [9.9927467e-01 7.2531495e-04]
# The name is: Øyvind and the prediction is: [0.31943014 0.68056977]
# The name is: Aleksander and the prediction is: [9.99898672e-01 1.01352176e-04]
# The name is: Rune and the prediction is: [0.6487644 0.3512356]
# The name is: Wei and the prediction is: [0.94078803 0.05921198]
# The name is: Aleksandar and the prediction is: [9.9914205e-01 8.5786835e-04]
# The name is: Diem and the prediction is: [0.4540264 0.5459736]
# The name is: Trude and the prediction is: [0.5305823 0.4694177]
# The name is: Ivar and the prediction is: [0.9054048  0.09459517]
# The name is: Niels and the prediction is: [0.9980393  0.00196075]
# The name is: Kjetil and the prediction is: [0.9557134  0.04428666]
# The name is: Kristine and the prediction is: [5.1472052e-06 9.9999487e-01]
# The name is: Lars and the prediction is: [9.9927467e-01 7.2531495e-04]
# The name is: Mudassar and the prediction is: [0.97621524 0.02378477]
# The name is: Shaukat and the prediction is: [0.99680823 0.00319169]
# The name is: Janne and the prediction is: [6.0582015e-04 9.9939418e-01]
# The name is: Sarry and the prediction is: [0.07438987 0.92561007]
# The name is: Jan and the prediction is: [0.94735533 0.05264461]
# The name is: Lukasz and the prediction is: [9.9977201e-01 2.2800309e-04]
# The name is: John and the prediction is: [0.9875563 0.0124437]
# The name is: Cathal and the prediction is: [0.2931193 0.7068807]
# The name is: Thomas and the prediction is: [0.07485382 0.9251462 ]
# The name is: Trine and the prediction is: [0.03080754 0.96919245]
# The name is: Lasse and the prediction is: [0.9419831 0.0580169]
# The name is: Irene and the prediction is: [0.001875 0.998125]
# The name is: Trine and the prediction is: [0.03080754 0.96919245]
# The name is: Olav and the prediction is: [0.98675483 0.01324518]
# The name is: Angel and the prediction is: [0.7754035  0.22459656]
# The name is: Arthur and the prediction is: [0.72442526 0.2755748 ]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Jonas and the prediction is: [0.940605   0.05939496]
# The name is: Alf and the prediction is: [9.999565e-01 4.353825e-05]
# The name is: Kristine and the prediction is: [5.1472052e-06 9.9999487e-01]
# The name is: Edward and the prediction is: [9.9999738e-01 2.5980462e-06]
# The name is: Gøril and the prediction is: [0.09801611 0.9019839 ]
# The name is: Yusuf and the prediction is: [0.72119415 0.27880582]
# The name is: Audun and the prediction is: [0.7917909  0.20820908]
# The name is: Jonathan and the prediction is: [9.9999583e-01 4.1548283e-06]
# The name is: Siri and the prediction is: [0.05762023 0.94237983]
# The name is: Andreas and the prediction is: [9.9973243e-01 2.6758359e-04]
# The name is: Tina and the prediction is: [1.0665174e-06 9.9999893e-01]
# The name is: Abbas and the prediction is: [0.9980252  0.00197485]
# The name is: Nils and the prediction is: [0.9874693  0.01253075]
# The name is: Lihua and the prediction is: [0.07084421 0.92915577]
# The name is: Gunnar and the prediction is: [9.9966121e-01 3.3880273e-04]
# The name is: Lars and the prediction is: [9.9927467e-01 7.2531495e-04]
# The name is: Angela and the prediction is: [3.222594e-05 9.999678e-01]
# The name is: Bengt and the prediction is: [0.92944777 0.07055221]
# The name is: Ghazala and the prediction is: [0.18944731 0.8105527 ]
# The name is: Thomas and the prediction is: [0.07485382 0.9251462 ]
# The name is: Ellen and the prediction is: [0.01560154 0.9843985 ]
# The name is: Paulo and the prediction is: [0.8775483  0.12245172]
# The name is: Ngan and the prediction is: [0.06792833 0.9320717 ]
# The name is: Jay and the prediction is: [0.99362963 0.0063704 ]
# The name is: Linh and the prediction is: [0.46098515 0.5390149 ]
# The name is: Lyder and the prediction is: [0.8925163  0.10748369]
# The name is: Erlend and the prediction is: [0.92011094 0.07988904]
# The name is: Thomas and the prediction is: [0.07485382 0.9251462 ]
# The name is: Tora and the prediction is: [0.03057412 0.9694259 ]
# The name is: Mohammad and the prediction is: [9.996014e-01 3.985437e-04]
# The name is: Eivind and the prediction is: [0.03622585 0.96377414]
# The name is: Nina and the prediction is: [3.6629476e-06 9.9999630e-01]
# The name is: Frank and the prediction is: [0.5071813 0.4928187]
# The name is: Olle and the prediction is: [0.2991568 0.7008432]
# The name is: Odd and the prediction is: [0.98556036 0.01443963]
# The name is: Åsa and the prediction is: [0.03662975 0.96337026]
# The name is: Svein and the prediction is: [0.99659353 0.00340641]
# The name is: Bekim and the prediction is: [0.99730057 0.0026994 ]
# The name is: Mahmood and the prediction is: [0.97188675 0.02811333]
# The name is: Thor and the prediction is: [0.7784508  0.22154924]
# The name is: Morad and the prediction is: [0.9985368  0.00146318]
# The name is: Etem and the prediction is: [0.4878101  0.51218987]
# The name is: Johan and the prediction is: [0.9311729  0.06882713]
# The name is: Kjersti and the prediction is: [5.8713584e-05 9.9994123e-01]
# The name is: Ivar and the prediction is: [0.9054048  0.09459517]
# The name is: Tina and the prediction is: [1.0665174e-06 9.9999893e-01]
# The name is: Marc and the prediction is: [0.98897076 0.01102932]
# The name is: Quang and the prediction is: [0.8712472  0.12875283]
# The name is: Marit and the prediction is: [0.07400985 0.92599016]
# The name is: Knut and the prediction is: [0.95275253 0.04724744]
# The name is: Atli and the prediction is: [0.07642969 0.9235703 ]
# The name is: Fikret and the prediction is: [0.47585985 0.5241402 ]
# The name is: Mohammed and the prediction is: [9.9977440e-01 2.2555844e-04]
# The name is: Ulf and the prediction is: [0.9928965  0.00710355]
# The name is: Mia and the prediction is: [0.01000866 0.9899913 ]
# The name is: Nguyet and the prediction is: [0.04806395 0.95193607]
# The name is: Eva and the prediction is: [0.00113123 0.99886876]
# The name is: Pål and the prediction is: [0.9776963  0.02230366]
# The name is: Tou and the prediction is: [0.90922934 0.09077071]
# The name is: Wahab and the prediction is: [0.87242264 0.12757735]
# The name is: Zahra and the prediction is: [0.08439168 0.9156083 ]
# The name is: Harald and the prediction is: [9.9997604e-01 2.4001620e-05]
# The name is: Salma and the prediction is: [9.5403004e-05 9.9990463e-01]
# The name is: Homeyra and the prediction is: [2.5165332e-06 9.9999750e-01]
# The name is: Karl and the prediction is: [0.99283594 0.00716403]
# The name is: Victoria and the prediction is: [2.4549786e-07 9.9999976e-01]
# The name is: Anne and the prediction is: [3.867471e-04 9.996132e-01]
# The name is: Raja and the prediction is: [0.12687582 0.8731242 ]
# The name is: Tony and the prediction is: [0.9450181  0.05498192]
# The name is: Simen and the prediction is: [0.38362482 0.6163752 ]
# The name is: Mehmet and the prediction is: [0.8313401 0.1686599]
# The name is: Runar and the prediction is: [0.9729393  0.02706066]
# The name is: Patrick and the prediction is: [9.9985325e-01 1.4672983e-04]
# The name is: Kemal and the prediction is: [0.995854   0.00414597]
# The name is: Markus and the prediction is: [9.9983120e-01 1.6876053e-04]
# The name is: Andreas and the prediction is: [9.9973243e-01 2.6758359e-04]
# The name is: Tore and the prediction is: [0.95754695 0.04245313]
# The name is: Mahdi and the prediction is: [0.99448806 0.00551191]
# The name is: Björn and the prediction is: [9.999976e-01 2.422697e-06]
# The name is: Hege and the prediction is: [0.93257093 0.06742906]
# The name is: Morten and the prediction is: [0.9462331  0.05376688]
# The name is: Zafer and the prediction is: [0.961254   0.03874594]
# The name is: Kardo and the prediction is: [0.9979989  0.00200106]
# The name is: Petter and the prediction is: [0.80547    0.19453004]
# The name is: Massimo and the prediction is: [0.9151293  0.08487073]
# The name is: Xuanlei and the prediction is: [0.21801373 0.7819863 ]
# The name is: Caroline and the prediction is: [2.441385e-10 1.000000e+00]
# The name is: Ling and the prediction is: [0.22555126 0.77444875]
# The name is: Karina and the prediction is: [0.00135429 0.9986457 ]
# The name is: Cong and the prediction is: [0.86576736 0.13423261]
# The name is: Salam and the prediction is: [0.8786843  0.12131576]
# The name is: Mette and the prediction is: [0.0835097  0.91649026]
# The name is: Asle and the prediction is: [0.24938183 0.7506182 ]
# The name is: Daniel and the prediction is: [0.9933357 0.0066643]
# The name is: Geir and the prediction is: [0.98203665 0.01796332]
# The name is: Nadeem and the prediction is: [0.8297013  0.17029867]
# The name is: Alexander and the prediction is: [9.999994e-01 5.865879e-07]
# The name is: Elise and the prediction is: [0.00793008 0.9920699 ]
# The name is: Ziad and the prediction is: [0.9971372  0.00286283]
# The name is: Mohamed and the prediction is: [9.9999726e-01 2.6881917e-06]
# The name is: Gorm and the prediction is: [0.99542373 0.00457621]
# The name is: Thomas and the prediction is: [0.07485382 0.9251462 ]
# The name is: Moufid and the prediction is: [9.9918789e-01 8.1209186e-04]
# The name is: Sajid and the prediction is: [9.993303e-01 6.697346e-04]
# The name is: Eivind and the prediction is: [0.03622585 0.96377414]
# The name is: Jarle and the prediction is: [0.03667203 0.963328  ]
# The name is: Jeganathan and the prediction is: [9.9993145e-01 6.8543028e-05]
# The name is: Rebecca and the prediction is: [1.8228752e-04 9.9981779e-01]
# The name is: Barbro and the prediction is: [0.05291358 0.94708645]
# The name is: Lisbet and the prediction is: [4.6860487e-07 9.9999952e-01]
# The name is: Rune and the prediction is: [0.6487644 0.3512356]
# The name is: Ranbir and the prediction is: [9.9991465e-01 8.5309315e-05]
# The name is: Baldev and the prediction is: [9.9930990e-01 6.9009844e-04]
# The name is: Synne and the prediction is: [0.00207082 0.9979292 ]
# The name is: Sofia and the prediction is: [2.4900428e-04 9.9975103e-01]
# The name is: Manuel and the prediction is: [9.9989653e-01 1.0342964e-04]
# The name is: Aisha and the prediction is: [1.0048112e-05 9.9998999e-01]
# The name is: Issa and the prediction is: [0.42833325 0.5716667 ]
# The name is: Torstein and the prediction is: [0.99624676 0.00375318]
# The name is: Kjersti and the prediction is: [5.8713584e-05 9.9994123e-01]
# The name is: Nicolaj and the prediction is: [9.999964e-01 3.525910e-06]
# The name is: Aurora and the prediction is: [0.00142568 0.99857426]
# The name is: Yat and the prediction is: [0.963104 0.036896]
# The name is: Jasmina and the prediction is: [4.6405045e-04 9.9953592e-01]
# The name is: Dag and the prediction is: [0.9888609  0.01113912]
# The name is: Azeem and the prediction is: [9.9930227e-01 6.9766393e-04]
# The name is: Rupinder and the prediction is: [0.31882966 0.68117034]
# The name is: Mads and the prediction is: [0.99641234 0.00358772]
# The name is: Stig and the prediction is: [0.69127876 0.3087213 ]
# The name is: Caroline and the prediction is: [2.441385e-10 1.000000e+00]
# The name is: Shafqat and the prediction is: [0.95229334 0.04770666]
# The name is: Stein and the prediction is: [0.99771    0.00228997]
# The name is: Lars and the prediction is: [9.9927467e-01 7.2531495e-04]
# The name is: Jasvir and the prediction is: [9.999958e-01 4.178766e-06]
# The name is: Khodadad and the prediction is: [0.45827726 0.54172283]
# The name is: Matthew and the prediction is: [9.9957794e-01 4.2207475e-04]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Mikael and the prediction is: [9.9986744e-01 1.3249450e-04]
# The name is: Fredrik and the prediction is: [9.9996066e-01 3.9306058e-05]
# The name is: Sandra and the prediction is: [9.471282e-05 9.999052e-01]
# The name is: Odd and the prediction is: [0.98556036 0.01443963]
# The name is: Carlo and the prediction is: [0.98996055 0.0100394 ]
# The name is: Azhar and the prediction is: [9.990983e-01 9.016641e-04]
# The name is: Mohammad and the prediction is: [9.996014e-01 3.985437e-04]
# The name is: Roger and the prediction is: [0.9976078 0.0023922]
# The name is: Christian and the prediction is: [0.9952348  0.00476517]
# The name is: Anna and the prediction is: [1.3141868e-04 9.9986851e-01]
# The name is: Kulwinder and the prediction is: [0.8618071 0.1381929]
# The name is: Sandra and the prediction is: [9.471282e-05 9.999052e-01]
# The name is: Tor and the prediction is: [0.9480622  0.05193776]
# The name is: Cathrine and the prediction is: [6.4939675e-05 9.9993503e-01]
# The name is: David and the prediction is: [9.999751e-01 2.492560e-05]
# The name is: Marjolein and the prediction is: [7.157121e-07 9.999993e-01]
# The name is: Carl and the prediction is: [0.99059653 0.00940345]
# The name is: Anna and the prediction is: [1.3141868e-04 9.9986851e-01]
# The name is: Linnéa and the prediction is: [0.00152847 0.99847156]
# The name is: Anne and the prediction is: [3.867471e-04 9.996132e-01]
# The name is: Suraj and the prediction is: [0.99194664 0.00805333]
# The name is: Odd and the prediction is: [0.98556036 0.01443963]
# The name is: Kabinjit and the prediction is: [0.93662876 0.06337132]
# The name is: Mahmoud and the prediction is: [9.9968052e-01 3.1949527e-04]
# The name is: Rune and the prediction is: [0.6487644 0.3512356]
# The name is: Sukhbir and the prediction is: [0.5412272  0.45877287]
# The name is: Mai and the prediction is: [0.02279825 0.9772018 ]
# The name is: Englantina and the prediction is: [2.8910524e-06 9.9999714e-01]
# The name is: Arne and the prediction is: [0.93294257 0.06705745]
# The name is: Carl and the prediction is: [0.99059653 0.00940345]
# The name is: Morten and the prediction is: [0.9462331  0.05376688]
# The name is: Hong and the prediction is: [0.9205445  0.07945553]
# The name is: Kjetil and the prediction is: [0.9557134  0.04428666]
# The name is: Øivind and the prediction is: [0.04638968 0.95361036]
# The name is: Thomas and the prediction is: [0.07485382 0.9251462 ]
# The name is: Rodrigo and the prediction is: [9.9997520e-01 2.4836643e-05]
# The name is: Einar and the prediction is: [0.9699388  0.03006123]
# The name is: Mohammad and the prediction is: [9.996014e-01 3.985437e-04]
# The name is: Duc and the prediction is: [0.9776769  0.02232305]
# The name is: Linda and the prediction is: [1.4244340e-04 9.9985754e-01]
# The name is: Adam and the prediction is: [0.94975644 0.05024357]
# The name is: Jamal and the prediction is: [0.99119264 0.00880731]
# The name is: Niels and the prediction is: [0.9980393  0.00196075]
# The name is: Nakil and the prediction is: [0.83060646 0.1693935 ]
# The name is: Mohamad and the prediction is: [9.9999344e-01 6.5698005e-06]
# The name is: Ping and the prediction is: [0.21588448 0.7841155 ]
# The name is: Parinya and the prediction is: [9.4018981e-04 9.9905986e-01]
# The name is: Houcine and the prediction is: [0.76812    0.23187995]
# The name is: Soran and the prediction is: [0.9604619  0.03953813]
# The name is: Tone and the prediction is: [0.7302718 0.2697282]
# The name is: Joanne and the prediction is: [1.5445221e-06 9.9999845e-01]
# The name is: Øistein and the prediction is: [9.9949634e-01 5.0369074e-04]
# The name is: Sebastian and the prediction is: [9.9969506e-01 3.0495386e-04]
# The name is: Tobias and the prediction is: [0.9935183  0.00648171]
# The name is: Einar and the prediction is: [0.9699388  0.03006123]
# The name is: Nayat and the prediction is: [0.11817732 0.88182265]
# The name is: Veronica and the prediction is: [1.8673585e-08 1.0000000e+00]
# The name is: Dheeraj and the prediction is: [0.995449   0.00455098]
# The name is: Arne and the prediction is: [0.93294257 0.06705745]
# The name is: Daniel and the prediction is: [0.9933357 0.0066643]
# The name is: Salih and the prediction is: [0.958188   0.04181201]
# The name is: Kardo and the prediction is: [0.9979989  0.00200106]
# The name is: Kristian and the prediction is: [0.9445449  0.05545508]
# The name is: Eyvind and the prediction is: [0.34354156 0.65645844]
# The name is: Henning and the prediction is: [0.8732291  0.12677093]
# The name is: Deepak and the prediction is: [0.8096221  0.19037788]
# The name is: Oddbjørn and the prediction is: [9.9999595e-01 4.1044500e-06]
# The name is: Anne and the prediction is: [3.867471e-04 9.996132e-01]
# The name is: Stian and the prediction is: [0.960796   0.03920402]
# The name is: Frode and the prediction is: [0.6919592  0.30804083]
# The name is: Jacob and the prediction is: [9.9985433e-01 1.4568605e-04]
# The name is: Jocelyn and the prediction is: [1.2763658e-07 9.9999988e-01]
# The name is: Jeremy and the prediction is: [9.9929678e-01 7.0321106e-04]
# The name is: Christine and the prediction is: [5.915377e-07 9.999994e-01]
# The name is: Bjørnar and the prediction is: [0.9509815  0.04901842]
# The name is: Lasse and the prediction is: [0.9419831 0.0580169]
# The name is: Ahmed and the prediction is: [9.9999666e-01 3.3661875e-06]
# The name is: Seigo and the prediction is: [0.9701744  0.02982559]
# The name is: Hasan and the prediction is: [9.9924266e-01 7.5733301e-04]
# The name is: Jon and the prediction is: [0.5652946 0.4347054]
# The name is: Martin and the prediction is: [9.9990094e-01 9.8996468e-05]
# The name is: Helene and the prediction is: [4.962754e-08 1.000000e+00]
# The name is: Khizer and the prediction is: [9.9999809e-01 1.9076479e-06]
# The name is: Mats and the prediction is: [0.9980229  0.00197712]
# The name is: Karim and the prediction is: [0.6898089 0.3101911]
# The name is: Heidi and the prediction is: [0.00521642 0.9947836 ]
# The name is: Thomas and the prediction is: [0.07485382 0.9251462 ]
# The name is: You and the prediction is: [0.62846553 0.37153456]
# The name is: Abdurrahman and the prediction is: [9.9989784e-01 1.0220938e-04]
# The name is: Kamel and the prediction is: [0.14555505 0.8544449 ]
# The name is: Adelheid and the prediction is: [0.25753424 0.74246573]
# The name is: Suleyman and the prediction is: [0.9924765  0.00752345]
# The name is: Davide and the prediction is: [9.999641e-01 3.591757e-05]
# The name is: Mona and the prediction is: [0.00109533 0.9989047 ]
# The name is: Adam and the prediction is: [0.94975644 0.05024357]
# The name is: Margrethe and the prediction is: [3.3495130e-06 9.9999666e-01]
# The name is: Marianne and the prediction is: [1.5465649e-07 9.9999988e-01]
# The name is: Abdallah and the prediction is: [9.9999785e-01 2.1667333e-06]
# The name is: Lars and the prediction is: [9.9927467e-01 7.2531495e-04]
# The name is: Alan and the prediction is: [0.9858272  0.01417275]
# The name is: Ali and the prediction is: [0.08481064 0.9151893 ]
# The name is: Abdul and the prediction is: [0.9970933  0.00290673]
# The name is: Pascal and the prediction is: [0.8014866  0.19851337]
# The name is: Umaya and the prediction is: [0.00206943 0.9979305 ]
# The name is: Melike and the prediction is: [0.03478667 0.9652133 ]
# The name is: Pontus and the prediction is: [0.9304078  0.06959214]
# The name is: Ali and the prediction is: [0.08481064 0.9151893 ]
# The name is: Karim and the prediction is: [0.6898089 0.3101911]
# The name is: Jeevarajah and the prediction is: [9.9961996e-01 3.7997399e-04]
# The name is: Elvira and the prediction is: [2.2600138e-06 9.9999774e-01]
# The name is: Jannecke and the prediction is: [1.7344107e-06 9.9999821e-01]
# The name is: Elin and the prediction is: [0.1515963  0.84840375]
# The name is: Meng and the prediction is: [0.82171464 0.17828532]
# The name is: Hai and the prediction is: [0.78304124 0.21695876]
# The name is: Michelle and the prediction is: [5.6034096e-06 9.9999440e-01]
# The name is: Tone and the prediction is: [0.7302718 0.2697282]
# The name is: Tore and the prediction is: [0.95754695 0.04245313]
# The name is: Jennie and the prediction is: [0.0014835 0.9985165]
# The name is: Mathias and the prediction is: [9.9976319e-01 2.3686304e-04]
# The name is: Ayla and the prediction is: [8.9504437e-07 9.9999905e-01]
# The name is: Audun and the prediction is: [0.7917909  0.20820908]
# The name is: Huan and the prediction is: [0.9007728 0.0992272]
# The name is: Jon and the prediction is: [0.5652946 0.4347054]
# The name is: Xiaojun and the prediction is: [0.19046293 0.8095371 ]
# The name is: Peter and the prediction is: [0.96484375 0.03515626]
# The name is: Maria and the prediction is: [9.8452045e-05 9.9990153e-01]
# The name is: Tuyet and the prediction is: [0.48090374 0.51909626]
# The name is: Frederic and the prediction is: [9.9973267e-01 2.6730003e-04]
# The name is: Stein and the prediction is: [0.99771    0.00228997]
# The name is: Jihad and the prediction is: [0.9965095  0.00349047]
# The name is: Jan and the prediction is: [0.94735533 0.05264461]
# The name is: Lars and the prediction is: [9.9927467e-01 7.2531495e-04]
# The name is: Vilde and the prediction is: [0.01259409 0.98740596]
# The name is: Lasse and the prediction is: [0.9419831 0.0580169]
# The name is: Trond and the prediction is: [9.9952483e-01 4.7513930e-04]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Håkon and the prediction is: [0.9784107  0.02158928]
# The name is: Anne and the prediction is: [3.867471e-04 9.996132e-01]
# The name is: Finn and the prediction is: [0.8758559  0.12414415]
# The name is: Yngvar and the prediction is: [0.9935137  0.00648621]
# The name is: Inger and the prediction is: [0.53580546 0.4641946 ]
# The name is: Yanet and the prediction is: [1.4913283e-04 9.9985087e-01]
# The name is: Abida and the prediction is: [1.142450e-04 9.998858e-01]
# The name is: Per and the prediction is: [0.5639187 0.4360813]
# The name is: Gunn and the prediction is: [0.41198438 0.58801556]
# The name is: Peer and the prediction is: [0.52350134 0.47649875]
# The name is: Elisabeth and the prediction is: [4.1938303e-08 1.0000000e+00]
# The name is: Eli and the prediction is: [0.30657572 0.6934243 ]
# The name is: Harpreet and the prediction is: [0.03558283 0.9644172 ]
# The name is: Dag and the prediction is: [0.9888609  0.01113912]
# The name is: Muhammad and the prediction is: [9.9997902e-01 2.0992024e-05]
# The name is: Rolf and the prediction is: [9.993451e-01 6.548089e-04]
# The name is: Mahaveer and the prediction is: [0.99556834 0.0044317 ]
# The name is: Vian and the prediction is: [0.48540762 0.51459235]
# The name is: Binh and the prediction is: [0.93114686 0.06885318]
# The name is: Seungho and the prediction is: [0.92608064 0.0739194 ]
# The name is: Aadil and the prediction is: [0.994282   0.00571796]
# The name is: Jan and the prediction is: [0.94735533 0.05264461]
# The name is: Sindy and the prediction is: [0.10281966 0.8971803 ]
# The name is: Lars and the prediction is: [9.9927467e-01 7.2531495e-04]
# The name is: Minh and the prediction is: [0.6141573  0.38584265]
# The name is: Jørgen and the prediction is: [0.9976757  0.00232426]
# The name is: Shadi and the prediction is: [0.10182267 0.8981773 ]
# The name is: Runar and the prediction is: [0.9729393  0.02706066]
# The name is: Omid and the prediction is: [0.9984124  0.00158757]
# The name is: Aminder and the prediction is: [0.97629696 0.02370307]
# The name is: Bo and the prediction is: [0.2281062  0.77189374]
# The name is: Are and the prediction is: [0.8506284  0.14937158]
# The name is: Xiaofen and the prediction is: [0.93839234 0.06160767]
# The name is: Aleksander and the prediction is: [9.99898672e-01 1.01352176e-04]
# The name is: Sören and the prediction is: [0.05732203 0.9426779 ]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Ole and the prediction is: [0.29307315 0.7069268 ]
# The name is: Adam and the prediction is: [0.94975644 0.05024357]
# The name is: Zhi and the prediction is: [0.7477808  0.25221917]
# The name is: Karen and the prediction is: [0.04113195 0.958868  ]
# The name is: Jostein and the prediction is: [0.994279   0.00572097]
# The name is: Cassandra and the prediction is: [8.3099585e-06 9.9999166e-01]
# The name is: Eduardo and the prediction is: [9.9999332e-01 6.6788616e-06]
# The name is: Rasmus and the prediction is: [9.993291e-01 6.709779e-04]
# The name is: Jo and the prediction is: [0.00242934 0.9975707 ]
# The name is: Øivind and the prediction is: [0.04638968 0.95361036]
# The name is: Shamaila and the prediction is: [1.489444e-08 1.000000e+00]
# The name is: Lene and the prediction is: [9.6975290e-04 9.9903023e-01]
# The name is: Daljit and the prediction is: [0.9931855  0.00681445]
# The name is: Andreas and the prediction is: [9.9973243e-01 2.6758359e-04]
# The name is: Emil and the prediction is: [0.96702486 0.03297518]
# The name is: Songül and the prediction is: [0.01539363 0.9846064 ]
# The name is: Arnulf and the prediction is: [9.9993575e-01 6.4260195e-05]
# The name is: Bishnu and the prediction is: [0.99019647 0.0098035 ]
# The name is: Nina and the prediction is: [3.6629476e-06 9.9999630e-01]
# The name is: Julianne and the prediction is: [0.00152657 0.99847347]
# The name is: Morten and the prediction is: [0.9462331  0.05376688]
# The name is: Lisa and the prediction is: [4.1940046e-05 9.9995804e-01]
# The name is: Pernille and the prediction is: [7.0167675e-06 9.9999297e-01]
# The name is: Remy and the prediction is: [0.9830193  0.01698068]
# The name is: Maria and the prediction is: [9.8452045e-05 9.9990153e-01]
# The name is: Simret and the prediction is: [0.0060827 0.9939173]
# The name is: Pierre and the prediction is: [0.92263746 0.07736248]
# The name is: Phillip and the prediction is: [9.995090e-01 4.910043e-04]
# The name is: Halit and the prediction is: [0.854825   0.14517504]
# The name is: Rizgar and the prediction is: [0.9371368  0.06286316]
# The name is: Sissel and the prediction is: [1.8098397e-05 9.9998188e-01]
# The name is: Lucas and the prediction is: [0.9929797  0.00702034]
# The name is: Celine and the prediction is: [1.0571837e-06 9.9999893e-01]
# The name is: Petter and the prediction is: [0.80547    0.19453004]
# The name is: Trygve and the prediction is: [9.9989665e-01 1.0335037e-04]
# The name is: Janvi and the prediction is: [0.00296669 0.99703336]
# The name is: Sharon and the prediction is: [0.00168069 0.9983193 ]
# The name is: Jan and the prediction is: [0.94735533 0.05264461]
# The name is: Li and the prediction is: [0.05133018 0.9486698 ]
# The name is: Aleksey and the prediction is: [9.9966717e-01 3.3285044e-04]
# The name is: Marthe and the prediction is: [0.03274902 0.967251  ]
# The name is: Ketil and the prediction is: [0.13108711 0.8689129 ]
# The name is: Rolf and the prediction is: [9.993451e-01 6.548089e-04]
# The name is: Abdul and the prediction is: [0.9970933  0.00290673]
# The name is: Tarje and the prediction is: [0.9623049  0.03769513]
# The name is: Laila and the prediction is: [9.2747183e-07 9.9999905e-01]
# The name is: Parviz and the prediction is: [0.9421061  0.05789384]
# The name is: Julie and the prediction is: [0.05676021 0.9432398 ]
# The name is: Jimmy and the prediction is: [0.7422357  0.25776428]
# The name is: Peter and the prediction is: [0.96484375 0.03515626]
# The name is: Akfa and the prediction is: [0.04214162 0.95785844]
# The name is: Jakob and the prediction is: [9.9998844e-01 1.1599929e-05]
# The name is: Mohammed and the prediction is: [9.9977440e-01 2.2555844e-04]
# The name is: Le and the prediction is: [0.64199054 0.35800946]
# The name is: Jan and the prediction is: [0.94735533 0.05264461]
# The name is: Imran and the prediction is: [0.9121091  0.08789095]
# The name is: Prayut and the prediction is: [0.76072997 0.23927003]
# The name is: Benedicte and the prediction is: [0.00371326 0.99628675]
# The name is: Khan and the prediction is: [0.99760723 0.00239278]
# The name is: Line and the prediction is: [0.00570607 0.99429387]
# The name is: Karl and the prediction is: [0.99283594 0.00716403]
# The name is: Ann and the prediction is: [0.0190923  0.98090774]
# The name is: Eva and the prediction is: [0.00113123 0.99886876]
# The name is: Ramin and the prediction is: [0.9914487  0.00855127]
# The name is: Andre and the prediction is: [0.997997   0.00200296]
# The name is: Richard and the prediction is: [9.9971873e-01 2.8120173e-04]
# The name is: Peter and the prediction is: [0.96484375 0.03515626]
# The name is: Geir and the prediction is: [0.98203665 0.01796332]
# The name is: Sebastian and the prediction is: [9.9969506e-01 3.0495386e-04]
# The name is: Sjur and the prediction is: [0.90288967 0.09711036]
# The name is: Deniz and the prediction is: [0.08075865 0.91924137]
# The name is: Tarje and the prediction is: [0.9623049  0.03769513]
# The name is: Svein and the prediction is: [0.99659353 0.00340641]
# The name is: Karl-Henning and the prediction is: [9.614045e-05 9.999038e-01]
# The name is: Tor-Egil and the prediction is: [0.6568244  0.34317556]
# The name is: Øyvind and the prediction is: [0.31943014 0.68056977]
# The name is: Viri and the prediction is: [0.18352003 0.8164799 ]
# The name is: Eirik and the prediction is: [0.9968105  0.00318944]
# The name is: Yngve and the prediction is: [0.02902802 0.97097206]
# The name is: Pål and the prediction is: [0.9776963  0.02230366]
# The name is: Jacopo and the prediction is: [0.97498465 0.02501538]
# The name is: Magnus and the prediction is: [0.97110873 0.02889123]
# The name is: Yassin and the prediction is: [0.997924   0.00207598]
# The name is: Chunle and the prediction is: [0.75443053 0.24556953]
# The name is: Niclas and the prediction is: [9.9902916e-01 9.7089889e-04]
# The name is: Laura and the prediction is: [0.0315968 0.9684032]
# The name is: Ole and the prediction is: [0.29307315 0.7069268 ]
# The name is: Thomas and the prediction is: [0.07485382 0.9251462 ]
# The name is: Eva-Maria and the prediction is: [1.443852e-05 9.999856e-01]
# The name is: Haakon and the prediction is: [9.9996912e-01 3.0879317e-05]
# The name is: Elisabeth and the prediction is: [4.1938303e-08 1.0000000e+00]
# The name is: Kay and the prediction is: [0.90517753 0.09482244]
# The name is: Diana and the prediction is: [6.3934414e-05 9.9993610e-01]
# The name is: Perinpanathan and the prediction is: [1.000000e+00 1.842174e-08]
# The name is: Vimalan and the prediction is: [0.9367325  0.06326751]
# The name is: Idun and the prediction is: [0.78216094 0.21783909]
# The name is: Eva and the prediction is: [0.00113123 0.99886876]
# The name is: Karl-Axel and the prediction is: [0.53559697 0.46440303]
# The name is: Siv and the prediction is: [0.9899905  0.01000949]
# The name is: Ingunn and the prediction is: [0.10512755 0.8948725 ]
# The name is: Per and the prediction is: [0.5639187 0.4360813]
# The name is: Johan and the prediction is: [0.9311729  0.06882713]
# The name is: Stian and the prediction is: [0.960796   0.03920402]
# The name is: Pål and the prediction is: [0.9776963  0.02230366]
# The name is: Naweed and the prediction is: [0.83935744 0.16064258]
# The name is: Philip and the prediction is: [9.9960476e-01 3.9520525e-04]
# The name is: Eva and the prediction is: [0.00113123 0.99886876]
# The name is: Nathan and the prediction is: [9.999999e-01 8.992027e-08]
# The name is: Klas and the prediction is: [9.992513e-01 7.486295e-04]
# The name is: Inger and the prediction is: [0.53580546 0.4641946 ]
# The name is: Knut and the prediction is: [0.95275253 0.04724744]
# The name is: Benjamin and the prediction is: [9.9999988e-01 6.2473944e-08]
# The name is: Juan and the prediction is: [0.771713   0.22828692]
# The name is: Stine and the prediction is: [0.07535177 0.9246483 ]
# The name is: Wai and the prediction is: [0.97390795 0.02609206]
# The name is: Annie and the prediction is: [3.579799e-04 9.996420e-01]
# ...
# The name is: Elizabeth and the prediction is: [1.1076633e-08 1.0000000e+00]
# The name is: Siri and the prediction is: [0.05762023 0.94237983]
# The name is: Kennet and the prediction is: [9.9952435e-01 4.7562370e-04]
# The name is: Tore and the prediction is: [0.95754695 0.04245313]
# The name is: Anette and the prediction is: [3.0268127e-05 9.9996972e-01]
# The name is: Duy and the prediction is: [0.9963008  0.00369914]
# The name is: Jawad and the prediction is: [0.9845077  0.01549229]
# The name is: Bendik and the prediction is: [0.55607593 0.44392407]
# The name is: Yalgin and the prediction is: [0.05833513 0.9416649 ]
# The name is: Waris and the prediction is: [0.9950271  0.00497287]
# The name is: Tariq and the prediction is: [0.9890216  0.01097842]
# The name is: Juan and the prediction is: [0.771713   0.22828692]
# The name is: Emma and the prediction is: [0.00237716 0.9976228 ]
# The name is: Peter and the prediction is: [0.96484375 0.03515626]
# The name is: Mertefe and the prediction is: [0.15471089 0.84528905]
# The name is: Colin and the prediction is: [0.99655557 0.00344441]
# The name is: Stig and the prediction is: [0.69127876 0.3087213 ]
# The name is: Torstein and the prediction is: [0.99624676 0.00375318]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Marta and the prediction is: [0.00648031 0.9935197 ]
# The name is: Asad and the prediction is: [0.99576205 0.00423802]
# The name is: Tora and the prediction is: [0.03057412 0.9694259 ]
# The name is: Lam and the prediction is: [0.80499446 0.19500557]
# The name is: Lars-Jørgen and the prediction is: [0.0447272  0.95527285]
# The name is: Lena and the prediction is: [2.7765825e-08 1.0000000e+00]
# The name is: Man and the prediction is: [0.7477188  0.25228116]
# The name is: Jørn and the prediction is: [0.96074617 0.03925382]
# The name is: Rachna and the prediction is: [0.01583496 0.9841651 ]
# The name is: Ann and the prediction is: [0.0190923  0.98090774]
# The name is: Anusuiya and the prediction is: [0.0373568  0.96264327]
# The name is: Rafael and the prediction is: [0.9976636  0.00233641]
# The name is: Tara and the prediction is: [1.0193314e-04 9.9989808e-01]
# The name is: Frank and the prediction is: [0.5071813 0.4928187]
# The name is: Rune and the prediction is: [0.6487644 0.3512356]
# The name is: Eivind and the prediction is: [0.03622585 0.96377414]
# The name is: Cato and the prediction is: [0.99487203 0.005128  ]
# The name is: Thor and the prediction is: [0.7784508  0.22154924]
# The name is: Sverre and the prediction is: [0.9101686  0.08983136]
# The name is: Frode and the prediction is: [0.6919592  0.30804083]
# The name is: André and the prediction is: [0.9527667  0.04723324]
# The name is: Gabriele and the prediction is: [8.063566e-06 9.999919e-01]
# The name is: Muzamal and the prediction is: [0.9756005  0.02439947]
# The name is: Bård and the prediction is: [0.9910876  0.00891241]
# The name is: Mubin and the prediction is: [0.70977587 0.29022416]
# The name is: Audun and the prediction is: [0.7917909  0.20820908]
# The name is: Joachim and the prediction is: [9.9980146e-01 1.9850381e-04]
# The name is: Paramjit and the prediction is: [0.92274374 0.07725624]
# The name is: Jathishya and the prediction is: [2.6095533e-04 9.9973899e-01]
# The name is: Baki and the prediction is: [0.92370635 0.07629365]
# The name is: Magne and the prediction is: [0.00104133 0.9989587 ]
# The name is: Marie and the prediction is: [0.00258369 0.99741626]
# The name is: Gurkirat and the prediction is: [0.9841158  0.01588421]
# The name is: Anne and the prediction is: [3.867471e-04 9.996132e-01]
# The name is: Odd and the prediction is: [0.98556036 0.01443963]
# The name is: Javed and the prediction is: [0.9658948 0.0341052]
# The name is: Fredrik and the prediction is: [9.9996066e-01 3.9306058e-05]
# The name is: Olav and the prediction is: [0.98675483 0.01324518]
# The name is: Giang and the prediction is: [0.80306196 0.19693801]
# The name is: Ilyas and the prediction is: [0.99865425 0.00134577]
# The name is: Thuy and the prediction is: [0.39457548 0.60542446]
# The name is: Erik and the prediction is: [0.9977958 0.0022042]
# The name is: Irina and the prediction is: [0.00241753 0.99758244]
# The name is: Nevio and the prediction is: [9.9984455e-01 1.5543569e-04]
# The name is: Dominic and the prediction is: [9.9934083e-01 6.5917941e-04]
# The name is: Hatice and the prediction is: [2.378749e-04 9.997621e-01]
# The name is: Adeel and the prediction is: [0.90154874 0.09845127]
# The name is: Mehmet and the prediction is: [0.8313401 0.1686599]
# The name is: Audunn and the prediction is: [0.6407579  0.35924208]
# The name is: Jan and the prediction is: [0.94735533 0.05264461]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Samantha and the prediction is: [3.9731349e-06 9.9999607e-01]
# The name is: Rolf and the prediction is: [9.993451e-01 6.548089e-04]
# The name is: Arslan and the prediction is: [0.9978885  0.00211149]
# The name is: Ole and the prediction is: [0.29307315 0.7069268 ]
# The name is: Ahmet and the prediction is: [0.9970258  0.00297426]
# The name is: Jianzhong and the prediction is: [0.93316597 0.06683395]
# The name is: Jørgen and the prediction is: [0.9976757  0.00232426]
# The name is: Baljinder and the prediction is: [0.86790675 0.13209327]
# The name is: Anders and the prediction is: [9.9988568e-01 1.1435998e-04]
# The name is: Mudassar and the prediction is: [0.97621524 0.02378477]
# The name is: Are and the prediction is: [0.8506284  0.14937158]
# The name is: Tomas and the prediction is: [0.96343905 0.03656089]
# The name is: Benjamin and the prediction is: [9.9999988e-01 6.2473944e-08]
# The name is: Vijay and the prediction is: [0.8933458  0.10665424]
# The name is: Fridtjof and the prediction is: [0.9971585  0.00284145]
# The name is: Kristin and the prediction is: [2.496664e-06 9.999975e-01]
# The name is: Aleksander and the prediction is: [9.99898672e-01 1.01352176e-04]
# The name is: Turi and the prediction is: [0.17821753 0.8217824 ]
# The name is: Fredric and the prediction is: [9.9985325e-01 1.4669121e-04]
# The name is: Alexandra and the prediction is: [3.462075e-05 9.999654e-01]
# The name is: Jens and the prediction is: [0.9853668  0.01463315]
# The name is: Nora and the prediction is: [0.03772851 0.96227145]
# The name is: Lene and the prediction is: [9.6975290e-04 9.9903023e-01]
# The name is: Morten and the prediction is: [0.9462331  0.05376688]
# The name is: Eric and the prediction is: [0.9980502  0.00194983]
# The name is: Øyvind and the prediction is: [0.31943014 0.68056977]
# The name is: Mathilde and the prediction is: [3.2913953e-04 9.9967086e-01]
# The name is: Rusong and the prediction is: [0.26463243 0.7353676 ]
# The name is: Luigi and the prediction is: [0.9006161  0.09938383]
# The name is: Vegard and the prediction is: [0.98543787 0.01456208]
# The name is: Jon and the prediction is: [0.5652946 0.4347054]
# The name is: Peter and the prediction is: [0.96484375 0.03515626]
# The name is: Arshad and the prediction is: [9.9996877e-01 3.1252181e-05]
# The name is: Ronny and the prediction is: [0.98942053 0.01057942]
# The name is: Ngoc and the prediction is: [0.42386493 0.5761351 ]
# The name is: Heini and the prediction is: [0.01333653 0.98666346]
# The name is: Christine and the prediction is: [5.915377e-07 9.999994e-01]
# The name is: Kim and the prediction is: [0.7929864  0.20701367]
# The name is: Mads and the prediction is: [0.99641234 0.00358772]
# The name is: Adil and the prediction is: [0.7485103 0.2514897]
# The name is: Steff and the prediction is: [0.94829285 0.05170713]
# The name is: Ahmet and the prediction is: [0.9970258  0.00297426]
# The name is: Knut-Erik and the prediction is: [0.99747854 0.00252146]
# The name is: Magnus and the prediction is: [0.97110873 0.02889123]
# The name is: Line and the prediction is: [0.00570607 0.99429387]
# The name is: Nicolai and the prediction is: [9.9991655e-01 8.3437379e-05]
# The name is: Kate and the prediction is: [0.41578513 0.58421487]
# The name is: Apichat and the prediction is: [9.9995542e-01 4.4539705e-05]
# The name is: Sergio and the prediction is: [9.9979919e-01 2.0080802e-04]
# The name is: Eirik and the prediction is: [0.9968105  0.00318944]
# The name is: Jenny and the prediction is: [0.07736114 0.9226388 ]
# The name is: Einar and the prediction is: [0.9699388  0.03006123]
# The name is: Anne and the prediction is: [3.867471e-04 9.996132e-01]
# The name is: Sven and the prediction is: [0.9907945  0.00920558]
# The name is: Misgina and the prediction is: [1.810266e-05 9.999819e-01]
# The name is: Morten and the prediction is: [0.9462331  0.05376688]
# The name is: Ingrid and the prediction is: [3.1732663e-04 9.9968266e-01]
# The name is: Ciscomar and the prediction is: [9.9937785e-01 6.2217540e-04]
# The name is: Simen and the prediction is: [0.38362482 0.6163752 ]
# The name is: Olaf and the prediction is: [0.8047058 0.1952942]
# The name is: Frøydis and the prediction is: [0.08108364 0.91891634]
# The name is: Maja and the prediction is: [0.00180705 0.99819297]
# The name is: Gerhard and the prediction is: [9.9998784e-01 1.2149348e-05]
# The name is: Vegard and the prediction is: [0.98543787 0.01456208]
# The name is: Mads and the prediction is: [0.99641234 0.00358772]
# The name is: Magdalena and the prediction is: [2.3806898e-10 1.0000000e+00]
# The name is: Feng and the prediction is: [0.3628494 0.6371506]
# The name is: Iftikhar and the prediction is: [9.999907e-01 9.259940e-06]
# The name is: Francisco and the prediction is: [9.9998939e-01 1.0596269e-05]
# The name is: Mai and the prediction is: [0.02279825 0.9772018 ]
# The name is: Salar and the prediction is: [0.8276698 0.1723302]
# The name is: Nira and the prediction is: [4.6745595e-04 9.9953258e-01]
# The name is: Saro and the prediction is: [0.92642796 0.07357205]
# The name is: Bjørn and the prediction is: [9.9995804e-01 4.1953888e-05]
# The name is: David and the prediction is: [9.999751e-01 2.492560e-05]
# The name is: Nevzat and the prediction is: [0.5703442  0.42965576]
# The name is: Jørn and the prediction is: [0.96074617 0.03925382]
# The name is: Jonas and the prediction is: [0.940605   0.05939496]
# The name is: Boge and the prediction is: [0.9878946  0.01210543]
# The name is: Vidar and the prediction is: [0.994365   0.00563498]
# The name is: Saliha and the prediction is: [2.316334e-04 9.997683e-01]
# The name is: Øystein and the prediction is: [0.9981962  0.00180378]
# The name is: Ole and the prediction is: [0.29307315 0.7069268 ]
# The name is: Natascha and the prediction is: [8.3346760e-07 9.9999917e-01]
# The name is: Walter and the prediction is: [0.46090758 0.53909236]
# The name is: Ida and the prediction is: [0.01963688 0.9803631 ]
# The name is: Ha and the prediction is: [0.0064941  0.99350584]
# The name is: Fredrik and the prediction is: [9.9996066e-01 3.9306058e-05]
# The name is: Ståle and the prediction is: [0.90901166 0.09098829]
# The name is: Lene and the prediction is: [9.6975290e-04 9.9903023e-01]
# The name is: Håkon and the prediction is: [0.9784107  0.02158928]
# The name is: Weibo and the prediction is: [0.86658895 0.13341108]
# The name is: Esben and the prediction is: [0.9968363 0.0031637]
# The name is: Harsamit and the prediction is: [9.9958640e-01 4.1360385e-04]
# The name is: Johnny and the prediction is: [0.9761979 0.0238021]
# The name is: Harpreet and the prediction is: [0.03558283 0.9644172 ]
# The name is: Silvia and the prediction is: [5.1221857e-04 9.9948776e-01]
# The name is: Asbjørn and the prediction is: [9.9998605e-01 1.3905804e-05]
# The name is: Thomas and the prediction is: [0.07485382 0.9251462 ]
# The name is: Adnan and the prediction is: [0.89527464 0.10472537]
# The name is: Saeed and the prediction is: [0.99776745 0.00223258]
# The name is: Petter and the prediction is: [0.80547    0.19453004]
# The name is: Bjørn and the prediction is: [9.9995804e-01 4.1953888e-05]
# The name is: Rune and the prediction is: [0.6487644 0.3512356]
# The name is: Van and the prediction is: [0.9123919  0.08760806]
# The name is: Abdul and the prediction is: [0.9970933  0.00290673]
# The name is: Ellen and the prediction is: [0.01560154 0.9843985 ]
# The name is: James and the prediction is: [0.84891284 0.15108715]
# The name is: Susanne and the prediction is: [2.4099554e-05 9.9997592e-01]
# The name is: Tomm and the prediction is: [0.9878395  0.01216044]
# The name is: Danny and the prediction is: [0.92184776 0.07815231]
# The name is: Ole and the prediction is: [0.29307315 0.7069268 ]
# The name is: Eugenia and the prediction is: [1.4844978e-05 9.9998510e-01]
# The name is: Tri and the prediction is: [0.3826281 0.6173719]
# The name is: Charlotta and the prediction is: [6.671101e-08 9.999999e-01]
# The name is: Gurkirt and the prediction is: [9.9997973e-01 2.0299667e-05]
# The name is: Sinnappu and the prediction is: [0.11475076 0.88524926]
# The name is: Lulzim and the prediction is: [0.9973979  0.00260216]
# The name is: James and the prediction is: [0.84891284 0.15108715]
# The name is: Kristin and the prediction is: [2.496664e-06 9.999975e-01]
# The name is: Marisa and the prediction is: [9.9805664e-05 9.9990022e-01]
# The name is: Anna and the prediction is: [1.3141868e-04 9.9986851e-01]
# The name is: Besim and the prediction is: [0.98098445 0.01901549]
# The name is: Tor and the prediction is: [0.9480622  0.05193776]
# The name is: Jonas and the prediction is: [0.940605   0.05939496]
# The name is: Joakim and the prediction is: [9.9986649e-01 1.3348593e-04]
# The name is: Anna-Carin and the prediction is: [2.0625301e-09 1.0000000e+00]
# The name is: Leif and the prediction is: [0.97223544 0.02776458]
# The name is: Cecilie and the prediction is: [2.8495173e-04 9.9971503e-01]
# The name is: Neha and the prediction is: [0.00330482 0.99669516]
# The name is: Christian and the prediction is: [0.9952348  0.00476517]
# The name is: Vivian and the prediction is: [0.01030616 0.9896938 ]
# The name is: Klaus and the prediction is: [0.9901322  0.00986775]
# The name is: Aleksander and the prediction is: [9.99898672e-01 1.01352176e-04]
# The name is: Aylin and the prediction is: [0.00458504 0.995415  ]
# The name is: Nina and the prediction is: [3.6629476e-06 9.9999630e-01]
# The name is: Tiril and the prediction is: [0.2687957 0.7312043]
# The name is: Bent and the prediction is: [9.9958724e-01 4.1273181e-04]
# The name is: Alex and the prediction is: [0.975104   0.02489606]
# The name is: Malin and the prediction is: [0.77580935 0.2241906 ]
# The name is: Zahid and the prediction is: [0.98132646 0.01867351]
# The name is: Øystein and the prediction is: [0.9981962  0.00180378]
# The name is: Waqas and the prediction is: [0.9906172  0.00938278]
# The name is: Iren and the prediction is: [0.16849358 0.8315064 ]
# The name is: Roger and the prediction is: [0.9976078 0.0023922]
# The name is: Sajid and the prediction is: [9.993303e-01 6.697346e-04]
# The name is: Alain and the prediction is: [0.91163427 0.0883657 ]
# The name is: Are and the prediction is: [0.8506284  0.14937158]
# The name is: Thi and the prediction is: [0.8061922  0.19380781]
# The name is: Kashmir and the prediction is: [0.28360003 0.71639997]
# The name is: Abdul and the prediction is: [0.9970933  0.00290673]
# The name is: Konrad and the prediction is: [0.99848396 0.00151604]
# The name is: Zanne and the prediction is: [0.00326046 0.99673957]
# The name is: Bakar and the prediction is: [0.9978302  0.00216979]
# The name is: Ronny and the prediction is: [0.98942053 0.01057942]
# The name is: Taiba and the prediction is: [0.01314982 0.98685014]
# The name is: Øystein and the prediction is: [0.9981962  0.00180378]
# The name is: Francesco and the prediction is: [9.9986768e-01 1.3231132e-04]
# The name is: Mahnaz and the prediction is: [0.02155495 0.9784451 ]
# The name is: Henrik and the prediction is: [9.9999785e-01 2.1492053e-06]
# The name is: Hassan and the prediction is: [9.999733e-01 2.666004e-05]
# The name is: Pawel and the prediction is: [0.95091784 0.04908221]
# The name is: Erlend and the prediction is: [0.92011094 0.07988904]
# The name is: Fred and the prediction is: [0.66122204 0.33877796]
# The name is: Camilla and the prediction is: [1.9838882e-07 9.9999976e-01]

# %%
sex = []
for value in predictions:
    if value[0] > value [1]:
        sex.append(1)
    else:
        sex.append(0)

# %%
people_data['sex'] = sex

# %%
people_data = people_data[['navn', 'person_id', 'sex']]

# %%
people_data
# Out:
#                                 navn  person_id  sex
# 0             Fredrik Kloster Hansen          0    1
# 1               Fredrik Øren Refsnes          1    1
# 2                Stian Bua Hellestad          2    1
# 3     Even Bernhard Bergstrøm Hegbom          3    1
# 4                    Mohammad Shahid          4    1
# ...                              ...        ...  ...
# 1848             Hassan Omar Ibrahim       1848    1
# 1849             Pawel Adrian Turala       1849    1
# 1850                   Erlend Nornes       1850    1
# 1851                Fred Arne Bakken       1851    1
# 1852        Camilla Bendixen Husevåg       1852    0
#
# [1853 rows x 3 columns]

# %%
# Data import
parent = path.abspath(path.join("03_gender_name_prediction.ipynb" ,"../../.."))
with open(f'{parent}/Data/Extracted/df_people_gender.obj', 'wb') as file:
	pickle.dump(people_data, file)

# %%
people_data
# Out:
#                                 navn  person_id  sex
# 0             Fredrik Kloster Hansen          0    1
# 1               Fredrik Øren Refsnes          1    1
# 2                Stian Bua Hellestad          2    1
# 3     Even Bernhard Bergstrøm Hegbom          3    1
# 4                    Mohammad Shahid          4    1
# ...                              ...        ...  ...
# 1848             Hassan Omar Ibrahim       1848    1
# 1849             Pawel Adrian Turala       1849    1
# 1850                   Erlend Nornes       1850    1
# 1851                Fred Arne Bakken       1851    1
# 1852        Camilla Bendixen Husevåg       1852    0
#
# [1853 rows x 3 columns]
