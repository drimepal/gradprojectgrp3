# %% [markdown]
# ## Script for processing and transforming pickle files to dataframes

# %%
import pickle
import pandas as pd

# %% [markdown]
# ##### Importing pickle file

# %%
with open(r'..\..\Data\Raw\scraped_data_from_brønnøysund.obj', 'rb') as file:
    scraped_bronnoysund_data = pickle.load(file)

# %% [markdown]
# ##### Creating dataframe

# %%
df = pd.DataFrame(scraped_bronnoysund_data)

# %%
print(type(scraped_bronnoysund_data))
# Out:
# <class 'list'>

# %%
print(scraped_bronnoysund_data[0])
# Out:
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="nb" xml:lang="nb">
#
#   <head>
# <meta charset="windows-1252"><meta name="viewport" content="width=device-width, initial-scale=1.0"/>
# <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
# <meta name="keywords" content="Brønnøysundregistrene"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags --><link rel="stylesheet" href="//scf.brreg.no/css/normalize.min.css"/><link rel="stylesheet" href="//scf.brreg.no/css/bootstrap.min.css?v=2"/>
# <link rel="stylesheet" href="//scf.brreg.no/fonts/open-sans/open-sans.css">
# <link rel="stylesheet" href="//scf.brreg.no/css/br.css?v=11">
# <link rel="stylesheet" href="//scf.brreg.no/css/framework.css?v=25">
# <script src="//scf.brreg.no/js/br.js?v=4" defer></script>
# <script id="frameworkScript" data-scf="//scf.brreg.no" data-www="https://www.brreg.no" src="//scf.brreg.no/js/framework.js?v=41" defer></script>
# ...
