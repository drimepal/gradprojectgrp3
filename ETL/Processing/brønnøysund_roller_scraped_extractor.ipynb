# %% [markdown]
# # Test file for extracting data from webscraped raw data

# %%
import os
import sys
import lxml
import pickle
import requests
import regex as re
import pandas as pd
import os.path as path
from copy import deepcopy
from bs4 import BeautifulSoup

sys.setrecursionlimit(10000)

# %% [markdown]
# #### Importing the raw scraped html data

# %%
parent = path.abspath(path.join("brønnøysund_roller_scraped_extractor.ipynb" ,"../../.."))
with open(f'{parent}/Data/Raw/scraped_data_from_brønnøysund.obj', 'rb') as file:
	raw_html_data = pickle.load(file)

# %%
print(len(raw_html_data))
# Out:
# 1003

# %%
def remove_seperators(row):
        
    result = ""
    line = str(row.text).strip()
    for character in line:
        #print(character)
        if character in ["\n", "\t"]:
            pass
            #break
        else:
            result = result + character
                    
    return result

# %%
def get_data_after(get_data_after, orgnumber, html_data):
    """Gets the data belonging to a category in a html file.

    Args:
        get_data_after (string): the name of a category e.g: Daglig leder/ adm.direktør:
        orgnumber (string): a 9 digit org number in string format.
        html_data (string): a string in html format, not parsed.

    Returns:
        list: returns a list with the values belonging to the category.
    """
    data = BeautifulSoup(html_data, 'lxml')
    get_data_after.strip()    
    acquired_data = False
    retrieve_data_rows = False
    retrieved_data = []
    
    for row in data.find_all('p'):
        if re.search("<b>[A-Z]", str(row)):
            retrieve_data_rows = False
        if retrieve_data_rows == True:
            if len(row.text) > 0 and row.text not in ["\n", "\n\n"]:
                retrieved_data.append(row.text)
                acquired_data = True
        if row.text == f"\n{get_data_after}\n":
            retrieve_data_rows = True
    
    if acquired_data == False:
        return False
    return retrieved_data

# %%
data_structure = {}
list_of_search_parameters = ["Daglig leder/ adm.direktør:", 
                            "Innehaver:",
                            "Kontaktperson:",
                            "Styrets leder:", 
                            "Nestleder:", 
                            "Styremedlem:",
                            "Varamedlem:"]

for key, value in raw_html_data.items():
    data_structure[key] = {}

    for search_parameter in list_of_search_parameters:
        data = get_data_after(get_data_after = search_parameter,
                                orgnumber = key,
                                html_data = value)
        if data != False:
            data_structure[key][search_parameter] = data

# %%
data_structure
# Out:
# {'927526891': {'Daglig leder/ adm.direktør:': ['Mehmet Celik'],
#   'Styrets leder:': ['Mehmet Celik'],
#   'Styremedlem:': ['Anette Wittingsrud Celik']},
#  '926646419': {'Daglig leder/ adm.direktør:': ['Mohamed Ali Saleh Ahmed'],
#   'Styrets leder:': ['Mubin Mohamed Ahmed'],
#   'Styremedlem:': ['Abdallah Abdi Hussein']},
#  '921505337': {'Daglig leder/ adm.direktør:': ['Gurkirt Singh'],
#   'Styrets leder:': ['Gurkirt Singh']},
#  '911956535': {'Daglig leder/ adm.direktør:': ['Sekoya Noreng'],
#   'Styrets leder:': ['Sekoya Noreng']},
#  '918928405': {'Daglig leder/ adm.direktør:': ['Tor Lundsholt'],
#   'Styrets leder:': ['Bjørn Tore Furset'],
#   'Styremedlem:': ['Gjøran Kvernes Sæther']},
#  '930727334': {'Daglig leder/ adm.direktør:': ['Suye Mon'],
#   'Styrets leder:': ['Tomas Adrian Glans'],
#   'Nestleder:': ['Anne Aarrestad']},
#  '928546861': {'Daglig leder/ adm.direktør:': ['Tharald Stray Laastad'],
#   'Styrets leder:': ['Tharald Stray Laastad'],
#   'Styremedlem:': ['Tore Kristian Tofte']},
#  '919741570': {'Daglig leder/ adm.direktør:': ['Mertefe Bartinlioglu'],
#   'Styrets leder:': ['Mertefe Bartinlioglu']},
#  '953964333': {'Daglig leder/ adm.direktør:': ['Tor-Egil Hasselstrøm'],
#   'Styrets leder:': ['Tor-Egil Hasselstrøm']},
#  '928334562': {'Daglig leder/ adm.direktør:': ['Samir Sharma'],
#   'Styrets leder:': ['Samir Sharma']},
#  '923161023': {'Daglig leder/ adm.direktør:': ['Victor Joseph Demison Lionel'],
#   'Styrets leder:': ['Victor Joseph Demison Lionel']},
#  '924579862': {'Daglig leder/ adm.direktør:': ['Karoline Thoner'],
#   'Styrets leder:': ['Magnus Egerdahl Nørsett'],
#   'Styremedlem:': ['Rudolf Reim', 'Karen Busck']},
#  '980147622': {'Kontaktperson:': ['Rodrigo Alejandro Lavin Belda'],
#   'Styrets leder:': ['Erik Tronbøl'],
#   'Styremedlem:': ['Rodrigo Alejandro Lavin Belda', 'Jan Ivar Sørensen']},
#  '922433704': {'Daglig leder/ adm.direktør:': ['Aksel Hanto Steen'],
#   'Styrets leder:': ['Aksel Hanto Steen']},
#  '915000967': {'Daglig leder/ adm.direktør:': ['Gyrd Helmuth Larsen'],
#   'Styrets leder:': ['Pratthana Silaporn']},
#  '917444250': {'Daglig leder/ adm.direktør:': ['Yu Chen'],
#   'Styrets leder:': ['Yu Chen']},
#  '914192900': {'Daglig leder/ adm.direktør:': ['Jay Dee Andre Romano'],
#   'Styrets leder:': ['Jocelyn Romano'],
#   'Nestleder:': ['Jonathan Uy Romano'],
#   'Styremedlem:': ['Jay Dee Andre Romano']},
#  '919035080': {'Daglig leder/ adm.direktør:': ['Tuyet Le Tran'],
#   'Styrets leder:': ['Tuyet Le Tran']},
#  '960317947': {'Daglig leder/ adm.direktør:': ['Lars Erik Underthun'],
#   'Styrets leder:': ['Torgeir Mjør Grimsrud'],
#   'Styremedlem:': ['Lars Erik Underthun', 'Lasse Søgaard']},
#  '991098577': {'Daglig leder/ adm.direktør:': ['Julie Marie Haugen'],
#   'Kontaktperson:': ['Klaus Inge Torp'],
#   'Styrets leder:': ['Klaus Inge Torp']},
#  '814599892': {'Daglig leder/ adm.direktør:': ['Giang Kim Hoang'],
#   'Styrets leder:': ['Giang Kim Hoang'],
#   'Varamedlem:': ['Lam Van Hoang']},
#  '921486456': {'Daglig leder/ adm.direktør:': ['Stine Gjørtz'],
#   'Styrets leder:': ['Atle Brynestad']},
#  '958596936': {'Daglig leder/ adm.direktør:': ['Mohammad Ayub Malik'],
#   'Styrets leder:': ['Prince Faisel Malik'],
#   'Varamedlem:': ['Saliha Lahchaychi']},
#  '917533695': {'Daglig leder/ adm.direktør:': ['Ahmed Brinis'],
#   'Styrets leder:': ['Ahmed Brinis']},
#  '929549287': {'Daglig leder/ adm.direktør:': ['Neha Vij'],
#   'Styrets leder:': ['Vikas Vij']},
#  '916020732': {'Daglig leder/ adm.direktør:': ['Yanzhong Lin'],
#   'Styrets leder:': ['Yanzhong Lin']},
#  '893105182': {'Innehaver:': ['Jan Erik Engblom']},
#  '977498201': {'Daglig leder/ adm.direktør:': ['Kristel Angelsen Berre'],
#   'Styrets leder:': ['Nevzat Arikan'],
#   'Styremedlem:': ['Johan Kristian Afzelius'],
#   'Varamedlem:': ['Halit Suha Coskuntuna']},
#  '986113258': {'Innehaver:': ['Frank Louis Frederik Rigal']},
#  '925677418': {'Daglig leder/ adm.direktør:': ['Thomas Pierre Martinho'],
#   'Styrets leder:': ['Frederic Jean Aguerre']},
#  '983194222': {'Daglig leder/ adm.direktør:': ['Stig Olle Friberg'],
#   'Styrets leder:': ['Bjørn Tore Furset'],
#   'Varamedlem:': ['Julie Hjorth-Eriksen Furset']},
#  '927642271': {'Daglig leder/ adm.direktør:': ['Laurentiu-Gabriel Megelea'],
#   'Styrets leder:': ['Brian John Kovary'],
#   'Styremedlem:': ['Stian Bjervamoen']},
#  '998657792': {'Daglig leder/ adm.direktør:': ['Ingrida Balseviciute'],
#   'Styrets leder:': ['Ingrida Balseviciute']},
#  '922310211': {'Daglig leder/ adm.direktør:': ['Saro Ismailzada'],
#   'Styrets leder:': ['Azhwan Hamzayi']},
#  '819177252': {'Daglig leder/ adm.direktør:': ['Ling Xiao Zheng'],
#   'Styrets leder:': ['Yennie Jie Zhen Feng'],
#   'Styremedlem:': ['Ling Xiao Zheng']},
#  '915888585': {'Daglig leder/ adm.direktør:': ['Terje Tuft'],
#   'Styrets leder:': ['Terje Tuft']},
#  '822942652': {'Daglig leder/ adm.direktør:': ['Trung Dung Thi Nguyen'],
#   'Styrets leder:': ['Trung Dung Thi Nguyen']},
#  '917235198': {'Daglig leder/ adm.direktør:': ['Feng Feng Lang'],
#   'Styrets leder:': ['Tuong Vinh Lang']},
#  '976633113': {'Daglig leder/ adm.direktør:': ['Rolf Fredrik Ekelund'],
#   'Styrets leder:': ['Rolf Fredrik Ekelund'],
#   'Styremedlem:': ['Audun Romstad Stavne']},
#  '913013034': {'Kontaktperson:': ['Javed Iqbal'],
#   'Styrets leder:': ['Javed Iqbal'],
#   'Nestleder:': ['Babar Javed Ali']},
#  '992206381': {'Daglig leder/ adm.direktør:': ['Kjell Rommetvedt'],
#   'Styrets leder:': ['Kjell Rommetvedt'],
#   'Varamedlem:': ['Rolf Smedvig Hodne']},
#  '918911847': {'Daglig leder/ adm.direktør:': ['Mahadi Wanthaphirom'],
#   'Styrets leder:': ['Mahadi Wanthaphirom']},
#  '920287298': {'Daglig leder/ adm.direktør:': ['Rahmat Faribarz'],
#   'Styrets leder:': ['Rahmat Faribarz'],
#   'Varamedlem:': ['Zahra Alizade']},
#  '920604412': {'Daglig leder/ adm.direktør:': ['Mohammad Kaleem Rahi'],
#   'Styrets leder:': ['Mohammad Kaleem Rahi']},
#  '816607922': {'Daglig leder/ adm.direktør:': ['Henry Nguyen'],
#   'Styrets leder:': ['Henry Nguyen']},
#  '965497633': {'Daglig leder/ adm.direktør:': ['Rolf Fredrik Ekelund'],
#   'Styrets leder:': ['Rolf Fredrik Ekelund'],
#   'Styremedlem:': ['Audun Romstad Stavne']},
#  '920799396': {'Daglig leder/ adm.direktør:': ['Mossa Hassan Abdul-Riza'],
#   'Styrets leder:': ['Mossa Hassan Abdul-Riza']},
#  '923031480': {'Daglig leder/ adm.direktør:': ['Sebastian Myhre'],
#   'Styrets leder:': ['Bo Vivike'],
#   'Styremedlem:': ['Sebastian Myhre', 'Are Sandved Lunde'],
#   'Varamedlem:': ['Anders Erik Nilsson']},
#  '915245595': {'Daglig leder/ adm.direktør:': ['Alia Anjum'],
#   'Styrets leder:': ['Kashif Jalil']},
#  '994216929': {'Daglig leder/ adm.direktør:': ['Meng Zhou'],
#   'Styrets leder:': ['Wei Wang'],
#   'Styremedlem:': ['Meng Zhou']},
#  '928120724': {'Daglig leder/ adm.direktør:': ['Jaime Aidan Lindquist-Docherty'],
#   'Styrets leder:': ['Arnt Olaf Andersen'],
#   'Styremedlem:': ['Eyvind Brox', 'Simen Vinge', 'Runar Skjerven Eggesvik']},
#  '980426106': {'Innehaver:': ['Ping Zhi Zhang']},
#  '998033926': {'Daglig leder/ adm.direktør:': ['Svein Rune Wisnes'],
#   'Styrets leder:': ['Svein Rune Wisnes'],
#   'Varamedlem:': ['Frank Herman Schønhardt']},
#  '990564728': {'Daglig leder/ adm.direktør:': ['Line Kristine Ringsby'],
#   'Styrets leder:': ['Alf Mangor Johannessen'],
#   'Styremedlem:': ['Line Kristine Ringsby']},
#  '990778590': {'Daglig leder/ adm.direktør:': ['Lars Joakim Gunler'],
#   'Styrets leder:': ['Lars Joakim Gunler'],
#   'Styremedlem:': ['Karl Markus Larsson', 'Bo Lars Erik Verneholt']},
#  '996075303': {'Daglig leder/ adm.direktør:': ['Zhelin Zhang'],
#   'Styrets leder:': ['Zhelin Zhang']},
#  '917405840': {'Daglig leder/ adm.direktør:': ['Khai Quang Tran'],
#   'Styrets leder:': ['Khai Quang Tran']},
#  '924601019': {'Styrets leder:': ['Hassan Omar Ibrahim']},
#  '923592881': {'Styrets leder:': ['Nils-Olav Oddanger-Heggdalsvik'],
#   'Styremedlem:': ['Jimmy Olafsen']},
#  '922597995': {'Daglig leder/ adm.direktør:': ['Abdul Rafay Hussain'],
#   'Styrets leder:': ['Qamar Abbas']},
#  '921067984': {'Daglig leder/ adm.direktør:': ['Khizer Bin Yaqub'],
#   'Styrets leder:': ['Elisabeth Vu Hoang']},
#  '925120863': {'Daglig leder/ adm.direktør:': ['Lasse Juul Horn'],
#   'Styrets leder:': ['Sandra Tolderlund Marquardsen'],
#   'Styremedlem:': ['Lasse Juul Horn']},
#  '919843888': {'Daglig leder/ adm.direktør:': ['Aminder Kaur'],
#   'Styrets leder:': ['Baljit Singh']},
#  '816607892': {'Daglig leder/ adm.direktør:': ['Henry Nguyen'],
#   'Styrets leder:': ['Henry Nguyen']},
#  '816565812': {'Styrets leder:': ['Mohsen Matory']},
#  '981061586': {'Daglig leder/ adm.direktør:': ['Ibrahim Arikan'],
#   'Styrets leder:': ['Ibrahim Arikan'],
#   'Varamedlem:': ['Nevzat Arikan']},
#  '987127554': {'Daglig leder/ adm.direktør:': ['Li Xing Wang'],
#   'Styrets leder:': ['Li Xing Wang'],
#   'Styremedlem:': ['Yan Sha', 'Zheng Dao Wang']},
#  '921727038': {'Daglig leder/ adm.direktør:': ['Jonas Berg Grønvold'],
#   'Styrets leder:': ['Tommy Gilen']},
#  '999031803': {'Daglig leder/ adm.direktør:': ['Sanjiv Sharma'],
#   'Styrets leder:': ['Sanjiv Sharma'],
#   'Varamedlem:': ['Rachna Sharma']},
#  '997097246': {'Daglig leder/ adm.direktør:': ['Remy Lorentsen'],
#   'Styrets leder:': ['Yat Fai Cheng'],
#   'Styremedlem:': ['Yat Shing Cheng', 'Yat Yiu Cheng']},
#  '918064370': {'Daglig leder/ adm.direktør:': ['Julie Marie Haugen'],
#   'Styrets leder:': ['Klaus Inge Torp']},
#  '925898619': {'Daglig leder/ adm.direktør:': ['Shadi Haj Yahia'],
#   'Styrets leder:': ['Sabah Omar Ali'],
#   'Styremedlem:': ['Shadi Haj Yahia', 'Sarry Haj Yahia']},
#  '927269813': {'Kontaktperson:': ['Rupinder Sharma'],
#   'Styrets leder:': ['Rupinder Sharma']},
#  '925077496': {'Daglig leder/ adm.direktør:': ['Simen Dalstein'],
#   'Styrets leder:': ['Simen Dalstein']},
#  '989872109': {'Daglig leder/ adm.direktør:': ['Kenn Krüsfeldt Zebitz'],
#   'Styrets leder:': ['Kenn Krüsfeldt Zebitz'],
#   'Styremedlem:': ['Mette Moe']},
#  '921567294': {'Daglig leder/ adm.direktør:': ['Ketil Skarshaug'],
#   'Styrets leder:': ['Emil Hesselberg'],
#   'Styremedlem:': ['Ketil Skarshaug']},
#  '995908271': {'Innehaver:': ['Arslan Ashraf']},
#  '991009272': {'Daglig leder/ adm.direktør:': ['Anna Kokolis'],
#   'Styrets leder:': ['Ioannis Moutafis'],
#   'Nestleder:': ['Anna Kokolis']},
#  '914000157': {'Daglig leder/ adm.direktør:': ['Tore Aamot'],
#   'Styrets leder:': ['Hallgeir Kristensen']},
#  '813317052': {'Daglig leder/ adm.direktør:': ['Laurent Jean-Pierre Vacarisas'],
#   'Styrets leder:': ['Laurent Jean-Pierre Vacarisas']},
#  '913649532': {'Kontaktperson:': ['Rodrigo Alejandro Lavin Belda'],
#   'Styrets leder:': ['Erik Tronbøl'],
#   'Styremedlem:': ['Rodrigo Alejandro Lavin Belda', 'Jan Ivar Sørensen']},
#  '898776182': {'Kontaktperson:': ['Kristin Dahle'],
#   'Styrets leder:': ['Kristin Dahle'],
#   'Styremedlem:': ['Thomas Tørstad Holmen', 'Stian Dahle Jakobsen']},
#  '994801600': {'Daglig leder/ adm.direktør:': ['Keen Chong Fann'],
#   'Styrets leder:': ['Øystein Dalsegg'],
#   'Styremedlem:': ['Keen Chong Fann']},
#  '815590872': {'Daglig leder/ adm.direktør:': ['Kjell Arne Johnsæter'],
#   'Styrets leder:': ['Richard Trygve Andvord'],
#   'Styremedlem:': ['Tore Namstad',
#    'Rune Sørum',
#    'Kristian Backe Schøning-Kristiansen']},
#  '917518262': {'Daglig leder/ adm.direktør:': ['Erik Pedersen'],
#   'Styrets leder:': ['Harald Perskaas'],
#   'Nestleder:': ['Hans Petter Brynildsen'],
#   'Styremedlem:': ['Erik Pedersen']},
#  '819032262': {'Daglig leder/ adm.direktør:': ['Tomm Munthe'],
#   'Styrets leder:': ['Nina Triber Munthe']},
#  '914852625': {'Daglig leder/ adm.direktør:': ['Deepak Sharma'],
#   'Styrets leder:': ['Anil Kumar Sharma'],
#   'Styremedlem:': ['Deepak Sharma', 'Olav Bæverfjord']},
#  '912651282': {'Daglig leder/ adm.direktør:': ['Håkon Dæhli'],
#   'Styrets leder:': ['Jan Erik Dæhli']},
#  '916913966': {'Daglig leder/ adm.direktør:': ['Aleksander Bråtho Gjølberg'],
#   'Styrets leder:': ['Asle Andersen']},
#  '921630727': {'Daglig leder/ adm.direktør:': ['Rolf Fredrik Ekelund'],
#   'Styrets leder:': ['Rolf Fredrik Ekelund'],
#   'Styremedlem:': ['Audun Romstad Stavne']},
#  '927616262': {'Daglig leder/ adm.direktør:': ['Aleksander Komnæs Hegnar'],
#   'Styrets leder:': ['Alexander Vaage'],
#   'Styremedlem:': ['Carl Martin Jahren', 'Aleksander Komnæs Hegnar']},
#  '826597852': {'Daglig leder/ adm.direktør:': ['Mahnoor Mahmood'],
#   'Styrets leder:': ['Mahnoor Mahmood']},
#  '996049248': {'Daglig leder/ adm.direktør:': ['Rolf Fredrik Ekelund'],
#   'Styrets leder:': ['Rolf Fredrik Ekelund'],
#   'Styremedlem:': ['Audun Romstad Stavne']},
#  '998944473': {'Daglig leder/ adm.direktør:': ['Kaseem Mohammad'],
#   'Styrets leder:': ['Kaseem Mohammad'],
#   'Varamedlem:': ['Anjum Kaseem']},
#  '981995120': {'Daglig leder/ adm.direktør:': ['Cecilie Trøan Kjelsaas'],
#   'Styrets leder:': ['Niclas Bernstein Möller'],
#   'Styremedlem:': ['Mikael Peter Nilsson']},
#  '920484379': {'Daglig leder/ adm.direktør:': ['Linnéa Carolina Gustafsson'],
#   'Styrets leder:': ['Gry Holm'],
#   'Styremedlem:': ['Anne Kristi Koppang', 'Kristin Gjesvik Havig-Gjelseth']},
#  '925147141': {'Daglig leder/ adm.direktør:': ['Lars Havn Gilleberg'],
#   'Styrets leder:': ['Pål Henrik Kristiansen'],
#   'Styremedlem:': ['Stein Inge Leirbekk', 'Lars Havn Gilleberg']},
#  '825397272': {'Daglig leder/ adm.direktør:': ['Neha Vij'],
#   'Styrets leder:': ['Neha Vij']},
#  '990473471': {'Daglig leder/ adm.direktør:': ['Ole Jonny Eikefjord'],
#   'Styrets leder:': ['Mads Breder Koch'],
#   'Styremedlem:': ['Ole Jonny Eikefjord'],
#   'Varamedlem:': ['Torgeir Silseth']},
#  '913144066': {'Daglig leder/ adm.direktør:': ['Catherina Xiang Hong Lian'],
#   'Styrets leder:': ['Catherina Xiang Hong Lian']},
#  '826685522': {'Daglig leder/ adm.direktør:': ['Rebecca Cecilia Töllinen'],
#   'Styrets leder:': ['Rebecca Cecilia Töllinen']},
#  '998316588': {'Daglig leder/ adm.direktør:': ['Hans Thorne'],
#   'Styrets leder:': ['Hans Thorne'],
#   'Nestleder:': ['Knut Glad']},
#  '974681196': {'Innehaver:': ['Rita Finnerud Larsen']},
#  '966381175': {'Daglig leder/ adm.direktør:': ['Stephen Tormod Landsverk'],
#   'Styrets leder:': ['Rolf Hongseth'],
#   'Nestleder:': ['Stephen Tormod Landsverk']},
#  '917212562': {'Daglig leder/ adm.direktør:': ['Victoria Ionela Angell'],
#   'Styrets leder:': ['Victoria Ionela Angell'],
#   'Styremedlem:': ['Thomas André Angell']},
#  '921731892': {'Daglig leder/ adm.direktør:': ['Akanksha Shrivastava'],
#   'Styrets leder:': ['Akanksha Shrivastava'],
#   'Styremedlem:': ['Parag Shrivastava']},
#  '927069911': {'Daglig leder/ adm.direktør:': ['Cathinka Rørtveit'],
#   'Styrets leder:': ['Cathinka Rørtveit']},
#  '974403307': {'Daglig leder/ adm.direktør:': ['Kawal Preet Singh Kahlon'],
#   'Styrets leder:': ['Daljinder Pal Singh Kahlon'],
#   'Varamedlem:': ['Kawal Preet Singh Kahlon']},
#  '826445912': {'Daglig leder/ adm.direktør:': ['Andre Melchior Larssen'],
#   'Styrets leder:': ['Andre Melchior Larssen']},
#  '994277294': {'Daglig leder/ adm.direktør:': ['Aylin Beigi'],
#   'Styrets leder:': ['Aylin Beigi'],
#   'Varamedlem:': ['Mahnaz Younesi']},
#  '983443400': {'Daglig leder/ adm.direktør:': ['Knut Olaf Wesenberg'],
#   'Styrets leder:': ['Pål Christian Suarez'],
#   'Styremedlem:': ['Knut Olaf Wesenberg',
#    'Ingun Hetager Suarez',
#    'Knut Brottveit'],
#   'Varamedlem:': ['Sverre Sivertsen']},
#  '985884366': {'Daglig leder/ adm.direktør:': ['Kjell Thomas Berg'],
#   'Styrets leder:': ['Kjell Thomas Berg'],
#   'Styremedlem:': ['Ellen Dorothea Brandt']},
#  '991678840': {'Daglig leder/ adm.direktør:': ['Ole Jonny Eikefjord'],
#   'Styrets leder:': ['Mads Breder Koch'],
#   'Styremedlem:': ['Ole Jonny Eikefjord']},
#  '923171355': {'Daglig leder/ adm.direktør:': ['Son Lam Bui'],
#   'Styrets leder:': ['Son Lam Bui']},
#  '923181873': {'Daglig leder/ adm.direktør:': ['Michael Angelo Weerasinghe'],
#   'Styrets leder:': ['Tora Daniela Moreiro Engh']},
#  '990154317': {'Daglig leder/ adm.direktør:': ['Claus Skovfoged'],
#   'Styrets leder:': ['Claus Skovfoged'],
#   'Styremedlem:': ['Eivind Saga', 'Bengt Christian Erliksson']},
#  '830516972': {'Daglig leder/ adm.direktør:': ['Are Kenneth Gald'],
#   'Styrets leder:': ['Thor Morten Halvorsen'],
#   'Styremedlem:': ['Pål Reinertsen', 'Morten Thorvaldsen']},
#  '823050232': {'Styrets leder:': ['Hasan Huseyin Dana']},
#  '996953750': {'Innehaver:': ['Salih Barzanjee']},
#  '919838639': {'Daglig leder/ adm.direktør:': ['Sajid Hussain'],
#   'Styrets leder:': ['Mohammad Gul Shahzad']},
#  '986382321': {'Daglig leder/ adm.direktør:': ['Rolf Fredrik Ekelund'],
#   'Styrets leder:': ['Rolf Fredrik Ekelund'],
#   'Styremedlem:': ['Audun Romstad Stavne']},
#  '884388562': {'Daglig leder/ adm.direktør:': ['Rune Sandvik'],
#   'Styrets leder:': ['Espen Hoff'],
#   'Styremedlem:': ['Kim Andre Klæbo']},
#  '996713997': {'Daglig leder/ adm.direktør:': ['Bjørn Ola Skjønsberg\n\t\t          \xa0\xa0\xa0\xa0\xa0\xa0Fratrådt\n                    '],
#   'Styrets leder:': ['Anders Bakken'],
#   'Styremedlem:': ['Aslak Førde', 'Hauk Eirik Jensen']},
#  '927836467': {'Daglig leder/ adm.direktør:': ['Kim Michael Johansson'],
#   'Styrets leder:': ['Kim Michael Johansson'],
#   'Styremedlem:': ['Stephi Pedersen']},
#  '922068135': {'Daglig leder/ adm.direktør:': ['Inger Marie Nordgård'],
#   'Styrets leder:': ['Inger Marie Nordgård']},
#  '930230871': {'Daglig leder/ adm.direktør:': ['Apichat Ninkumpee'],
#   'Styrets leder:': ['Apichat Ninkumpee'],
#   'Styremedlem:': ['Grethe Åsen']},
#  '918544623': {'Daglig leder/ adm.direktør:': ['Are Lied Nordtvedt'],
#   'Styrets leder:': ['Rune Mogens Pal']},
#  '985429847': {'Daglig leder/ adm.direktør:': ['Wenche Øyerhamn Magnussen'],
#   'Styrets leder:': ['Wenche Øyerhamn Magnussen'],
#   'Varamedlem:': ['Javeed Iqbal Khan']},
#  '991139435': {'Daglig leder/ adm.direktør:': ['Kjell Arne Johnsæter'],
#   'Styrets leder:': ['Richard Trygve Andvord'],
#   'Styremedlem:': ['Tore Namstad',
#    'Kristian Backe Schøning-Kristiansen',
#    'Rune Sørum']},
#  '918486380': {'Daglig leder/ adm.direktør:': ['Omar Ali Morad'],
#   'Styrets leder:': ['Omar Ali Morad']},
#  '898510042': {'Daglig leder/ adm.direktør:': ['Thu Van Nguyen'],
#   'Styrets leder:': ['Thu Van Nguyen'],
#   'Styremedlem:': ['Thuan Quoc Nguyen', 'Cindy Phan Nguyen']},
#  '974784564': {'Daglig leder/ adm.direktør:': ['Ziad Mahmood Abu Younis'],
#   'Styrets leder:': ['Ziad Mahmood Abu Younis']},
#  '917529922': {'Daglig leder/ adm.direktør:': ['Paolo Rossi'],
#   'Styrets leder:': ['Paolo Rossi']},
#  '920285481': {'Daglig leder/ adm.direktør:': ['Astrid Roppen'],
#   'Styrets leder:': ['Pål Roppen'],
#   'Styremedlem:': ['Odd Stian Floer\n\t\t        \xa0\xa0\xa0\xa0\xa0\xa0Fratrådt\n\t\t      ',
#    'Anders Braathen',
#    'Bård Roppen']},
#  '990319510': {'Daglig leder/ adm.direktør:': ['Merete Nilsen Bua'],
#   'Styrets leder:': ['Merete Nilsen Bua']},
#  '997045343': {'Daglig leder/ adm.direktør:': ['Bjørg Olaug Sjursen Fredskov'],
#   'Styrets leder:': ['Erik Keinicke Fredskov'],
#   'Varamedlem:': ['Bjørg Olaug Sjursen Fredskov']},
#  '912091171': {'Daglig leder/ adm.direktør:': ['Mertefe Bartinlioglu'],
#   'Styrets leder:': ['Mertefe Bartinlioglu']},
#  '911734044': {'Daglig leder/ adm.direktør:': ['Johan Kristian Afzelius'],
#   'Styrets leder:': ['Nevzat Arikan'],
#   'Varamedlem:': ['Halit Suha Coskuntuna']},
#  '927532611': {'Styrets leder:': ['Michael Ray Vera Cruz Angeles'],
#   'Styremedlem:': ['Chirag Rashmikant Patel',
#    'Misgina Gherense Ghebremeskel']},
#  '913731336': {'Daglig leder/ adm.direktør:': ['Erik Pedersen'],
#   'Styrets leder:': ['Harald Perskaas'],
#   'Styremedlem:': ['Erik Pedersen', 'Pål Henrik Kristiansen']},
#  '997767853': {'Daglig leder/ adm.direktør:': ['Jakob Helmut Thier'],
#   'Styrets leder:': ['Jakob Helmut Thier'],
#   'Styremedlem:': ['Erwin Neuhold'],
#   'Varamedlem:': ['Liv Gulborg Røed Thier', 'Anne-Mari Neuhold']},
#  '999630464': {'Daglig leder/ adm.direktør:': ['Marta Malgorzata Hrabia'],
#   'Styrets leder:': ['Marta Malgorzata Hrabia']},
#  '824486522': {'Daglig leder/ adm.direktør:': ['Liang Ge'],
#   'Styrets leder:': ['Liang Ge']},
#  '927610299': {'Daglig leder/ adm.direktør:': ['Kristyna Koberska'],
#   'Styrets leder:': ['Ondrej Vychodil']},
#  '915647774': {'Daglig leder/ adm.direktør:': ['Carl Fredrik Samson'],
#   'Styrets leder:': ['Per Christian Samson'],
#   'Styremedlem:': ['Carl Fredrik Samson', 'Morten Samson']},
#  '917994552': {'Daglig leder/ adm.direktør:': ['Jan Agne Mikael Wallsin'],
#   'Styrets leder:': ['Jan Agne Mikael Wallsin'],
#   'Styremedlem:': ['Lars Patrik Back']},
#  '926543148': {'Daglig leder/ adm.direktør:': ['Maria Bogdana Ianko'],
#   'Styrets leder:': ['Arnt Olaf Andersen'],
#   'Styremedlem:': ['Runar Skjerven Eggesvik', 'Eyvind Brox']},
#  '921296819': {'Daglig leder/ adm.direktør:': ['Arvin Reyes Aquilizan'],
#   'Styrets leder:': ['John Fredrick Teano Abellera'],
#   'Styremedlem:': ['Arvin Reyes Aquilizan',
#    'Dominic Dane Vergara',
#    'Mark Angelo Alcantara',
#    'Daniel Dave Vitug Vergara']},
#  '912737977': {'Daglig leder/ adm.direktør:': ['Stian Dahle Jakobsen'],
#   'Styrets leder:': ['Kristin Dahle'],
#   'Styremedlem:': ['Stian Dahle Jakobsen']},
#  '912258548': {'Daglig leder/ adm.direktør:': ['Jana Le'],
#   'Styrets leder:': ['Jana Le']},
#  '927089947': {'Daglig leder/ adm.direktør:': ['Erik Pedersen'],
#   'Styrets leder:': ['Harald Perskaas'],
#   'Styremedlem:': ['Erik Pedersen', 'Pål Henrik Kristiansen']},
#  '921251416': {'Styrets leder:': ['Ole Anh Huy Le']},
#  '986872884': {'Daglig leder/ adm.direktør:': ['Satwinder Singh'],
#   'Styrets leder:': ['Satwinder Singh'],
#   'Varamedlem:': ['Paramjit Kaur']},
#  '944384448': {'Daglig leder/ adm.direktør:': ['Adelheid Firing Hvambsal'],
#   'Styrets leder:': ['Geir Petter Isaksen'],
#   'Nestleder:': ['Knut Melbye Riksen'],
#   'Styremedlem:': ['Gøril Partapuoli Bjerkan',
#    'Anne Sophie Gangsøy',
#    'Jon Moslet',
#    'Petter Kjus Skippervold',
#    'Margrethe Sunde',
#    'Håkon Rasmussen',
#    'Anna Strandenæs'],
#   'Varamedlem:': ['Silje Elisabeth Stenvaag',
#    'Astrid Sandsmark',
#    'Eilert Christian Skjelvik Ottesen',
#    'Ottar Slettjord Skifte',
#    'Geir Mugaas',
#    'Anne Marie Lothe Strand']},
#  '982759129': {'Kontaktperson:': ['Tom Roger Olsen'],
#   'Styrets leder:': ['Tom Roger Olsen']},
#  '922859396': {'Daglig leder/ adm.direktør:': ['James Ian Maxwell-Stewart'],
#   'Styrets leder:': ['James Ian Maxwell-Stewart'],
#   'Styremedlem:': ['Thomas Alsgård']},
#  '911763176': {'Daglig leder/ adm.direktør:': ['Welliam Sada Lazar'],
#   'Styrets leder:': ['Welliam Sada Lazar'],
#   'Varamedlem:': ['David Sargon Mrkus']},
#  '926682083': {'Daglig leder/ adm.direktør:': ['Nils Filip Mikael Svensson'],
#   'Styrets leder:': ['Nils Filip Mikael Svensson']},
#  '954080072': {'Daglig leder/ adm.direktør:': ['Wai Koung Chan'],
#   'Styrets leder:': ['Yat Fai Cheng'],
#   'Styremedlem:': ['Yat Shing Cheng', 'Helge Rønn']},
#  '926627597': {'Daglig leder/ adm.direktør:': ['Ahmed Hassan Ali'],
#   'Styrets leder:': ['Andreas Skappel Holzweiler'],
#   'Styremedlem:': ['Susanne Holzweiler']},
#  '923590188': {'Daglig leder/ adm.direktør:': ['Nina Phi Phung Tran'],
#   'Styrets leder:': ['Nina Phi Phung Tran'],
#   'Styremedlem:': ['Phi Truong Tran']},
#  '924545402': {'Daglig leder/ adm.direktør:': ['Katrina Tania Locsin Cahigan'],
#   'Styrets leder:': ['Katrina Tania Locsin Cahigan'],
#   'Styremedlem:': ['Mark Anthony Del Carmen Cahigan']},
#  '921011288': {},
#  '984388608': {'Daglig leder/ adm.direktør:': ['Olav Bæverfjord'],
#   'Styrets leder:': ['Ralph Leo Lanckohr'],
#   'Styremedlem:': ['Matthias Meinl']},
#  '921174047': {'Daglig leder/ adm.direktør:': ['Omar Usman Ali'],
#   'Styrets leder:': ['Omar Usman Ali']},
#  '929049004': {'Daglig leder/ adm.direktør:': ['Nadeem Mahomed Dudhia'],
#   'Styrets leder:': ['Nadeem Mahomed Dudhia']},
#  '911581515': {'Daglig leder/ adm.direktør:': ['Pontus Tobias Dahlström'],
#   'Styrets leder:': ['Simon James Bartley'],
#   'Styremedlem:': ['Karina Lilleeng Holmen']},
#  '997284607': {'Daglig leder/ adm.direktør:': ['Fikret Kaya'],
#   'Styrets leder:': ['Güner Kaya']},
#  '828179942': {'Daglig leder/ adm.direktør:': ['Øyvind Kristiansen'],
#   'Styrets leder:': ['Richard Michael Andrew Sargeant'],
#   'Styremedlem:': ['David Mark Holmes']},
#  '915541585': {'Daglig leder/ adm.direktør:': ['Stian Mikalsen Sonerud'],
#   'Kontaktperson:': ['Tobias Mørland Kvaslerud'],
#   'Styrets leder:': ['Tobias Mørland Kvaslerud'],
#   'Styremedlem:': ['Sonja Hadland Haugen',
#    'Stian Mikalsen Sonerud',
#    'Markus Solvik',
#    'Audun Bakke Andersen',
#    'Kristian Sommerfelt Kjelstad',
#    'Henrik Heggland']},
#  '997045394': {'Daglig leder/ adm.direktør:': ['Petter Almås'],
#   'Styrets leder:': ['Simen Einebærholm'],
#   'Styremedlem:': ['Sven Erik Fuglerud Brastad',
#    'Aleksander Kuster Erichsen',
#    'Ole Petter Gilbo']},
#  '997991699': {'Daglig leder/ adm.direktør:': ['Tarje Haakstad'],
#   'Styrets leder:': ['Per Christensen'],
#   'Styremedlem:': ['Leif Kenneth Fjelde'],
#   'Varamedlem:': ['Tarje Haakstad']},
#  '979671008': {'Daglig leder/ adm.direktør:': ['Idun Kathrine Sæbjørnsen'],
#   'Styrets leder:': ['Idun Kathrine Sæbjørnsen'],
#   'Varamedlem:': ['Ann-May Larsen Waaler']},
#  '924474742': {'Daglig leder/ adm.direktør:': ['Kristian Alexis Azolas Ochoa'],
#   'Styrets leder:': ['Bjørn Tore Furset']},
#  '916186703': {'Daglig leder/ adm.direktør:': ['Stein Arve Bernes'],
#   'Styrets leder:': ['Richard Müller'],
#   'Varamedlem:': ['Morten Ahlbom']},
#  '923383395': {'Daglig leder/ adm.direktør:': ['Jamal Eddin Mohamad Almansour'],
#   'Styrets leder:': ['Simon Kefle Ocbab']},
#  '964651361': {'Daglig leder/ adm.direktør:': ['Jarle Friedrich Baer'],
#   'Styrets leder:': ['Jarle Friedrich Baer'],
#   'Varamedlem:': ['Frank Bodo Baer']},
#  '913708423': {'Daglig leder/ adm.direktør:': ['Yusuf Demirbas'],
#   'Styrets leder:': ['Yusuf Demirbas']},
#  '921973799': {'Innehaver:': ['Oda Karlsen Lyngås']},
#  '994668749': {'Daglig leder/ adm.direktør:': ['Ziryan Rizgar Mohamad'],
#   'Innehaver:': ['Rizgar Ahmad Mohamad']},
#  '924428546': {'Daglig leder/ adm.direktør:': ['Duy Huu Nguyen'],
#   'Styrets leder:': ['Helen Hang Phi Pham'],
#   'Styremedlem:': ['Duy Huu Nguyen']},
#  '999667171': {'Daglig leder/ adm.direktør:': ['Cemal Duzgun'],
#   'Styrets leder:': ['Cemal Duzgun']},
#  '917000409': {'Daglig leder/ adm.direktør:': ['Mohammed Amjad Hussain'],
#   'Styrets leder:': ['Mohammed Amjad Hussain']},
#  '920188826': {'Daglig leder/ adm.direktør:': ['Elisabeth Blikstad'],
#   'Styrets leder:': ['Elisabeth Blikstad'],
#   'Varamedlem:': ['Knut Andreas Hals']},
#  '824606552': {'Daglig leder/ adm.direktør:': ['Mathias Nilsson'],
#   'Styrets leder:': ['Simen Heie Torgersen']},
#  '930165719': {'Styrets leder:': ['Ann Sung-An Lee'],
#   'Styremedlem:': ['Montserrat Elizabeth Garza Pasaran']},
#  '928675122': {'Daglig leder/ adm.direktør:': ['Kamiran Ali Fares'],
#   'Styrets leder:': ['Amin Wisso Osman'],
#   'Styremedlem:': ['Rafat Mohyeddin Eibesh']},
#  '923359400': {'Daglig leder/ adm.direktør:': ['Ali Abbas Malik'],
#   'Styrets leder:': ['Ali Abbas Malik']},
#  '925583189': {'Daglig leder/ adm.direktør:': ['Cong Van Nguyen'],
#   'Styrets leder:': ['Cong Van Nguyen']},
#  '819552002': {'Daglig leder/ adm.direktør:': ['Hans Ingi Råheim Tryggvason'],
#   'Styrets leder:': ['Johanna Ellefsen Rostad'],
#   'Nestleder:': ['Ingrid Lønning'],
#   'Styremedlem:': ['Lars Vegard Vonen',
#    'Lars Aarflot',
#    'Hans Petter Akerholdt Gramer',
#    'Kristin Hjulstad Linderud']},
#  '995964449': {'Daglig leder/ adm.direktør:': ['Ove-André Jakobsen'],
#   'Styrets leder:': ['Ove-André Jakobsen'],
#   'Varamedlem:': ['Magdalena Rosenblad']},
#  '916776365': {'Daglig leder/ adm.direktør:': ['Tore Carlsson Sægrov'],
#   'Styrets leder:': ['Trine Lise Marsdal'],
#   'Styremedlem:': ['Espen Viig Syversen', 'Torgeir Silseth']},
#  '912517187': {'Daglig leder/ adm.direktør:': ['Baki Karakoc'],
#   'Styrets leder:': ['Baki Karakoc'],
#   'Varamedlem:': ['Songul Karakoc']},
#  '915354327': {'Styrets leder:': ['Jihad Lotfi Dasooqi']},
#  '928613143': {'Daglig leder/ adm.direktør:': ['Maren Moen Blomstereng'],
#   'Styrets leder:': ['Arnt Olaf Andersen'],
#   'Styremedlem:': ['Eyvind Brox', 'Runar Skjerven Eggesvik']},
#  '923992022': {'Daglig leder/ adm.direktør:': ['Azad Amedi'],
#   'Styrets leder:': ['Imad Ali Amedi']},
#  '925733636': {'Daglig leder/ adm.direktør:': ['Line Elisabeth Randhol'],
#   'Styrets leder:': ['Andrea Maria Rosa Marambio Fierro'],
#   'Styremedlem:': ['Frederik Rosenvinge Kolderup', 'Laura Raubaite'],
#   'Varamedlem:': ['Karl Olav Håheller Jensen']},
#  '920671942': {'Innehaver:': ['Dima Heger']},
#  '917123179': {'Daglig leder/ adm.direktør:': ['Jawad Afzal'],
#   'Styrets leder:': ['Navid Afzal']},
#  '916729332': {'Daglig leder/ adm.direktør:': ['Linh Luu'],
#   'Styrets leder:': ['Linh Luu']},
#  '826928972': {'Kontaktperson:': ['Runar Punktum Nordli-Olsen'],
#   'Styrets leder:': ['Fredric Folco Ruud Myhre'],
#   'Styremedlem:': ['Runar Punktum Nordli-Olsen']},
#  '982449979': {'Daglig leder/ adm.direktør:': ['Jørn Lie'],
#   'Styrets leder:': ['Lars Andreas Lie'],
#   'Styremedlem:': ['Jørn Lie', 'Pernille Høgli']},
#  '913289870': {'Daglig leder/ adm.direktør:': ['Sverre Glad Haug'],
#   'Styrets leder:': ['Ingrid Mjelva Opsal'],
#   'Styremedlem:': ['Jan Vardøen', 'Cathrine Haug Stange']},
#  '929729331': {'Daglig leder/ adm.direktør:': ['Rolf Fredrik Ekelund'],
#   'Styrets leder:': ['Rolf Fredrik Ekelund'],
#   'Styremedlem:': ['Audun Romstad Stavne']},
#  '914581702': {'Daglig leder/ adm.direktør:': ['Emil Hesselberg'],
#   'Styrets leder:': ['Michael Andre Henriksen']},
#  '913380665': {'Daglig leder/ adm.direktør:': ['Tonje Jeanette Fagerheim'],
#   'Styrets leder:': ['Tonje Jeanette Fagerheim'],
#   'Varamedlem:': ['Bror August Fagerheim']},
#  '923153713': {'Daglig leder/ adm.direktør:': ['Veslemøy Elisabeth Engh Hvidsten'],
#   'Styrets leder:': ['Lars-Jørgen Kroken'],
#   'Nestleder:': ['Veslemøy Elisabeth Engh Hvidsten'],
#   'Styremedlem:': ['Edward Joseph Shaw', 'Matija Kolar']},
#  '918681906': {'Daglig leder/ adm.direktør:': ['Waqas Ahmed'],
#   'Styrets leder:': ['Waqas Ahmed']},
#  '915182852': {'Styrets leder:': ['Salam Nuri Mohammed']},
#  '992064641': {'Daglig leder/ adm.direktør:': ['Thomas Lindberg'],
#   'Styrets leder:': ['Thomas Lindberg'],
#   'Varamedlem:': ['Hanne Søyland Lindberg']},
#  '921387229': {'Daglig leder/ adm.direktør:': ['Sajid Dad'],
#   'Styrets leder:': ['Sajid Dad']},
#  '928256715': {'Daglig leder/ adm.direktør:': ['Issa Borr'],
#   'Styrets leder:': ['Issa Borr']},
#  '926475363': {'Daglig leder/ adm.direktør:': ['Nils Brynildsen Sandegren'],
#   'Styrets leder:': ['Nils Brynildsen Sandegren'],
#   'Styremedlem:': ['Knut William Killmer', 'Joanne Brynildsen Sørheim']},
#  '923065881': {'Styrets leder:': ['Anders Johan Westerholm'],
#   'Styremedlem:': ['Matti Einari Sarkkinen']},
#  '929957377': {'Daglig leder/ adm.direktør:': ['Adam Schive Bjerck'],
#   'Styrets leder:': ['Adam Schive Bjerck'],
#   'Styremedlem:': ['Øyvind Bøe Dalelv']},
#  '913337441': {'Daglig leder/ adm.direktør:': ['Lene Haugland Søyland'],
#   'Styrets leder:': ['Lene Haugland Søyland'],
#   'Varamedlem:': ['Ivar Haugland']},
#  '984937296': {'Daglig leder/ adm.direktør:': ['Fibi Louise Bach Hagen'],
#   'Styrets leder:': ['Ronny Elemer Kiss'],
#   'Styremedlem:': ['Håkon Pettersen',
#    'Fibi Louise Bach Hagen',
#    'Trine Bach Hagen',
#    'Martine Bach Hagen']},
#  '976728599': {'Innehaver:': ['Mohammad Noor']},
#  '928701816': {'Daglig leder/ adm.direktør:': ['Dan Alexander Nypan'],
#   'Styrets leder:': ['Frederic Jean Aguerre']},
#  '920843794': {'Daglig leder/ adm.direktør:': ['Arkin Duzcu'],
#   'Styrets leder:': ['Arkin Duzcu']},
#  '919116870': {'Kontaktperson:': ['Hong Wang Ringman'],
#   'Styrets leder:': ['Hong Wang Ringman'],
#   'Styremedlem:': ['Jan Otto Ringman']},
#  '994203304': {'Daglig leder/ adm.direktør:': ['Marcus Jonathan Gustafsson'],
#   'Styrets leder:': ['Roger Halshamn'],
#   'Styremedlem:': ['Thomas Nordberg', 'Eivind Fallan']},
#  '924446072': {'Daglig leder/ adm.direktør:': ['Fredrik Andreas Larsen'],
#   'Styrets leder:': ['David Gurrik'],
#   'Styremedlem:': ['Fredrik Andreas Larsen',
#    'Sean Robert Mcdonald',
#    'Lars Nesser']},
#  '979372817': {'Daglig leder/ adm.direktør:': ['Harald Huysman'],
#   'Styrets leder:': ['Bård Martin Mikkelsen'],
#   'Styremedlem:': ['Marianne Johnsen Huysman',
#    'Harald Huysman',
#    'Bjørn-Erik Indahl',
#    'Odd Dagfinn Harlem',
#    'Bertel Otto Steen']},
#  '981118235': {'Kontaktperson:': ['Maria Cristina Enger Male'],
#   'Styrets leder:': ['Maria Cristina Enger Male'],
#   'Varamedlem:': ['Werner Male']},
#  '870534612': {'Daglig leder/ adm.direktør:': ['Ellen Iren Oldereid']},
#  '922907129': {'Daglig leder/ adm.direktør:': ['Antonio Corrado'],
#   'Styrets leder:': ['Antonio Corrado'],
#   'Styremedlem:': ['Kjersti Gjesdal',
#    'Giorgio Santonocito',
#    'Domenico Mirko Santonocito']},
#  '914787521': {'Daglig leder/ adm.direktør:': ['Carl Johan Viktor Aaby'],
#   'Styrets leder:': ['Karl Göran Mikael Palmquist'],
#   'Styremedlem:': ['Carl Johan Viktor Aaby',
#    'Ida Maria Christensson',
#    'Valery Christine Denise Henriquez',
#    'Sven-Helge Rühlmann',
#    'Mikael Næss',
#    'Bente Sofie Velken',
#    'Erik Walør Heggem'],
#   'Varamedlem:': ['Malene Valkvæ Jenssen',
#    'Khadya Nooraddin Khalil',
#    'Trine Nævdal']},
#  '989728741': {'Daglig leder/ adm.direktør:': ['Fredrik Krog Remmen'],
#   'Styrets leder:': ['Fredrik Krog Remmen'],
#   'Styremedlem:': ['Iren Storbråten Volden']},
#  '922388237': {'Daglig leder/ adm.direktør:': ['Aneta Florkowska'],
#   'Styrets leder:': ['Aneta Florkowska']},
#  '925502243': {'Daglig leder/ adm.direktør:': ['Nora Ingeborg Mortensen Workinn'],
#   'Styrets leder:': ['Frode Mortensen'],
#   'Nestleder:': ['Nora Ingeborg Mortensen Workinn']},
#  '927156601': {'Daglig leder/ adm.direktør:': ['Erik Pedersen'],
#   'Styrets leder:': ['Harald Perskaas'],
#   'Styremedlem:': ['Erik Pedersen', 'Pål Henrik Kristiansen']},
#  '971212667': {'Daglig leder/ adm.direktør:': ['Thomas Frank Pulpan'],
#   'Styrets leder:': ['Kristine Stranne'],
#   'Styremedlem:': ['Ivar Villa', 'Steinar Paulsrud', 'Johan Johannson']},
#  '868922532': {'Daglig leder/ adm.direktør:': ['Niphol Kavichai'],
#   'Styrets leder:': ['Yat Fai Cheng'],
#   'Styremedlem:': ['Yat Shing Cheng', 'Yat Yiu Cheng', 'Sean Cao']},
#  '996599507': {'Daglig leder/ adm.direktør:': ['Peter Espen Bengston'],
#   'Styrets leder:': ['Harald Marius Flaaten'],
#   'Styremedlem:': ['Fredrik Stray', 'Peter Espen Bengston']},
#  '925675938': {'Daglig leder/ adm.direktør:': ['Erik Pedersen'],
#   'Styrets leder:': ['Harald Perskaas'],
#   'Styremedlem:': ['Erik Pedersen', 'Pål Henrik Kristiansen']},
#  '998099307': {'Daglig leder/ adm.direktør:': ['Camilla Bendixen Husevåg'],
#   'Styrets leder:': ['Simen Einebærholm'],
#   'Styremedlem:': ['Erlend Karlseng']},
#  '917541019': {'Daglig leder/ adm.direktør:': ['Remzi Idrizi'],
#   'Styrets leder:': ['Remzi Idrizi']},
#  '916907346': {'Daglig leder/ adm.direktør:': ['Giti Azar'],
#   'Styrets leder:': ['Giti Azar']},
#  '981081803': {'Daglig leder/ adm.direktør:': ['Besim Mehaj'],
#   'Styrets leder:': ['Besim Mehaj'],
#   'Styremedlem:': ['Gunnar Jacob Steen', 'Jasmina Mehaj']},
#  '990035946': {'Daglig leder/ adm.direktør:': ['Tor Rønhovde'],
#   'Styrets leder:': ['Tor Rønhovde'],
#   'Styremedlem:': ['Finn Rune Kristiansen']},
#  '926337173': {'Daglig leder/ adm.direktør:': ['Harald Ayhan Robsahm Ulker\n\t\t          \xa0\xa0\xa0\xa0\xa0\xa0Fratrådt\n                    '],
#   'Styrets leder:': ['Harald Ayhan Robsahm Ulker\n\t\t        \xa0\xa0\xa0\xa0\xa0\xa0Fratrådt\n\t\t      '],
#   'Styremedlem:': ['Ali Nikoo\n\t\t        \xa0\xa0\xa0\xa0\xa0\xa0Fratrådt\n\t\t      ']},
#  '928430634': {'Daglig leder/ adm.direktør:': ['Jenny Jun Hu'],
#   'Styrets leder:': ['Jenny Jun Hu']},
#  '925855561': {'Daglig leder/ adm.direktør:': ['Haris Omanovic'],
#   'Styrets leder:': ['Øistein Kristiansen'],
#   'Styremedlem:': ['David Eggan Aune']},
#  '922096589': {'Daglig leder/ adm.direktør:': ['Mamta Rani'],
#   'Styrets leder:': ['Samir Prakash Khambekar']},
#  '892177732': {'Daglig leder/ adm.direktør:': ['Susanne Jensen'],
#   'Styrets leder:': ['Roger Halshamn'],
#   'Styremedlem:': ['Thomas Nordberg', 'Eivind Fallan']},
#  '915457681': {'Innehaver:': ['Tan Dat Huynh']},
#  '913298349': {'Daglig leder/ adm.direktør:': ['Tri Vinh Ngo'],
#   'Styrets leder:': ['Tri Vinh Ngo']},
#  '913708997': {'Daglig leder/ adm.direktør:': ['Birgitte Rommen'],
#   'Styrets leder:': ['Mai Britt Kristoffersen\n\t\t        \xa0\xa0\xa0\xa0\xa0\xa0Fratrådt\n\t\t      '],
#   'Styremedlem:': ['Birgitte Rommen']},
#  '938182132': {'Daglig leder/ adm.direktør:': ['Fridtjof Havig-Gjelseth',
#    'Markus Havig Gjelseth'],
#   'Styrets leder:': ['Tone Wicklund-Hansen'],
#   'Styremedlem:': ['Markus Havig Gjelseth',
#    'Inge Nygaard',
#    'Fridtjof Havig-Gjelseth',
#    'Vegard Hafsteen',
#    'Kristin Gjesvik Havig-Gjelseth',
#    'Anniken Havig-Gjelseth']},
#  '923583521': {'Daglig leder/ adm.direktør:': ['Anders Li'],
#   'Styrets leder:': ['Gabriela Janssen Baldo'],
#   'Styremedlem:': ['Camila Castilhos Lazzari'],
#   'Varamedlem:': ['Maria Alexandra Trenard Briceno']},
#  '925882143': {'Daglig leder/ adm.direktør:': ['Magnus Christopher Berner'],
#   'Styrets leder:': ['Magnus Christopher Berner'],
#   'Styremedlem:': ['Lasse Kjus',
#    'Magne Karlstad',
#    'Lene Undheim Berner',
#    'Michael Eeg',
#    'Kristine Cecilie Berentsen Windfeldt',
#    'Mike Eivind Hodne']},
#  '922899010': {'Daglig leder/ adm.direktør:': ['Tony Le'],
#   'Styrets leder:': ['Tony Le']},
#  '988144770': {'Daglig leder/ adm.direktør:': ['Aleksandar Surbat'],
#   'Styrets leder:': ['Aleksandar Surbat']},
#  '981674723': {'Daglig leder/ adm.direktør:': ['Jonathan Ante Janhed'],
#   'Styrets leder:': ['Nevzat Arikan'],
#   'Varamedlem:': ['Halit Suha Coskuntuna']},
#  '944802711': {'Daglig leder/ adm.direktør:': ['Gino Naim Alickaj'],
#   'Innehaver:': ['Gino Naim Alickaj']},
#  '922014728': {'Daglig leder/ adm.direktør:': ['Ali Issam Kanaan']},
#  '813801752': {'Daglig leder/ adm.direktør:': ['Jacob Elias Abrahamsen'],
#   'Styrets leder:': ['Jacob Elias Abrahamsen'],
#   'Styremedlem:': ['Turi Elisabeth Abrahamsen', 'Kristin Moe']},
#  '982321298': {'Daglig leder/ adm.direktør:': ['Yalgin Böcügöz'],
#   'Styrets leder:': ['Yalgin Böcügöz'],
#   'Styremedlem:': ['Fanny Böcügöz Ofstad Farestad'],
#   'Varamedlem:': ['Trine Seiersted Ofstad']},
#  '920741037': {'Daglig leder/ adm.direktør:': ['Houcine El Atiaoui'],
#   'Styrets leder:': ['Houcine El Atiaoui']},
#  '999086268': {'Daglig leder/ adm.direktør:': ['Karin Lillian Dejeborn'],
#   'Styrets leder:': ['Sigve Aspelund'],
#   'Styremedlem:': ['Karin Lillian Dejeborn', 'Rudolf Reim']},
#  '922555648': {'Innehaver:': ['Van Tuan Tran']},
#  '897583402': {'Daglig leder/ adm.direktør:': ['Xiaokun Wang'],
#   'Styrets leder:': ['Yuan Feng Ye'],
#   'Styremedlem:': ['Lei Ma'],
#   'Varamedlem:': ['Xiaokun Wang']},
#  '919265310': {'Daglig leder/ adm.direktør:': ['Anders Braathen'],
#   'Styrets leder:': ['Anders Braathen'],
#   'Styremedlem:': ['Tom Victor Gausdal',
#    'David Andrew Quist',
#    'Even Ramsvik']},
#  '916646615': {'Daglig leder/ adm.direktør:': ['Maria Liamaki'],
#   'Styrets leder:': ['Maria Liamaki']},
#  '917430861': {'Daglig leder/ adm.direktør:': ['Audunn Sletvold'],
#   'Styrets leder:': ['Simen Einebærholm'],
#   'Styremedlem:': ['Erlend Karlseng']},
#  '997026209': {'Daglig leder/ adm.direktør:': ['Thu Huong Thi Nguyen'],
#   'Styrets leder:': ['Thu Huong Thi Nguyen'],
#   'Styremedlem:': ['Guttorm Lindseth',
#    'Adriano Paolo Capoferro',
#    'Tore Bjørn Ottersland']},
#  '914491754': {'Daglig leder/ adm.direktør:': ['Carlo Tenace'],
#   'Styrets leder:': ['Carlo Tenace'],
#   'Varamedlem:': ['Susanna Feistmann']},
#  '912256014': {'Daglig leder/ adm.direktør:': ['Rolf Fredrik Ekelund'],
#   'Styrets leder:': ['Rolf Fredrik Ekelund'],
#   'Styremedlem:': ['Audun Romstad Stavne']},
#  '821624592': {'Daglig leder/ adm.direktør:': ['Espen Gjersvik'],
#   'Styrets leder:': ['Mads Breder Koch'],
#   'Styremedlem:': ['Ole Jonny Eikefjord']},
#  '918881050': {'Styrets leder:': ['Gabriele Kristine Neset']},
#  '888024042': {'Daglig leder/ adm.direktør:': ['Karl-Henning Fahlstrøm Svendsen'],
#   'Styrets leder:': ['Karl-Henning Fahlstrøm Svendsen'],
#   'Styremedlem:': ['Eddy Karen Egizarian', 'Morten Peter Usterud']},
#  '819725292': {'Daglig leder/ adm.direktør:': ['Nina Mariko Suizu Sandquist'],
#   'Innehaver:': ['Mohamadou Cherif Diallo']},
#  '916457146': {'Daglig leder/ adm.direktør:': ['Arnar Jakob Gudmundsson'],
#   'Styrets leder:': ['Jens Føien'],
#   'Styremedlem:': ['Anders Braathen',
#    'Tom Victor Gausdal',
#    'Hans Petter Hval',
#    'Arnar Jakob Gudmundsson',
#    'Even Ramsvik']},
#  '928234029': {'Daglig leder/ adm.direktør:': ['Maria Liamaki'],
#   'Styrets leder:': ['Maria Liamaki']},
#  '916998120': {'Daglig leder/ adm.direktør:': ['Anusuiya Timilsina'],
#   'Styrets leder:': ['Kiran Kafle']},
#  '968742752': {'Daglig leder/ adm.direktør:': ['Per Otto Hindahl'],
#   'Styrets leder:': ['Per Otto Hindahl'],
#   'Varamedlem:': ['Kim Kenneth Hindahl']},
#  '975360709': {'Innehaver:': ['Bjørn Inge Elvebredd']},
#  '925795690': {'Daglig leder/ adm.direktør:': ['Torstein Voksø Eek'],
#   'Styrets leder:': ['Arnt Olaf Andersen'],
#   'Styremedlem:': ['Eyvind Brox', 'Runar Skjerven Eggesvik']},
#  '817864902': {'Daglig leder/ adm.direktør:': ['Natalie Trang Tran Thi Thuy'],
#   'Styrets leder:': ['Natalie Trang Tran Thi Thuy']},
#  '982497515': {'Innehaver:': ['Henrik Heyerdahl Lorange']},
#  '928327973': {'Styrets leder:': ['Preben Falster'],
#   'Styremedlem:': ['Marianne Falster']},
#  '996057410': {'Daglig leder/ adm.direktør:': ['Svein Bjoland',
#    'Laura Sjasmin Marie Grisolia'],
#   'Styrets leder:': ['Svein Bjoland'],
#   'Varamedlem:': ['Vincenzo Grisolia']},
#  '921400632': {'Daglig leder/ adm.direktør:': ['Mohamad Kher Samir Harata'],
#   'Styrets leder:': ['Mohamad Kher Samir Harata']},
#  '925848727': {'Daglig leder/ adm.direktør:': ['Remo André Brodahl'],
#   'Styrets leder:': ['Remo André Brodahl'],
#   'Varamedlem:': ['Geir Otto Fagerslett']},
#  '928153134': {'Daglig leder/ adm.direktør:': ['Jørgen Andre Hansrud'],
#   'Styrets leder:': ['Magnus Egerdahl Nørsett'],
#   'Styremedlem:': ['Karen Busck', 'Rudolf Reim']},
#  '911548100': {'Daglig leder/ adm.direktør:': ['Bo Vivike'],
#   'Styrets leder:': ['Bo Vivike'],
#   'Styremedlem:': ['Sebastian Myhre', 'Are Sandved Lunde'],
#   'Varamedlem:': ['Anders Erik Nilsson']},
#  '996335518': {'Daglig leder/ adm.direktør:': ['Bo Vivike'],
#   'Styrets leder:': ['Bo Vivike'],
#   'Styremedlem:': ['Sebastian Myhre', 'Are Sandved Lunde'],
#   'Varamedlem:': ['Anders Erik Nilsson']},
#  '926598147': {'Daglig leder/ adm.direktør:': ['Victoria Alexsandra Brandvold'],
#   'Styrets leder:': ['Victoria Alexsandra Brandvold']},
#  '921861001': {'Daglig leder/ adm.direktør:': ['Stein Erik Jakobsen'],
#   'Styrets leder:': ['Maria Liamaki']},
#  '960658493': {'Daglig leder/ adm.direktør:': ['Fredrik Øren Refsnes'],
#   'Styrets leder:': ['Andreas Berggren Eskelund'],
#   'Styremedlem:': ['Gudleik Grimstad',
#    'Steffen Hekleberg Greff',
#    'Eva Strømme Moshuus',
#    'Silje Elden Wilhelmsen',
#    'Nira Nahum Reiersen',
#    'Sureerat Sukboonya'],
#   'Varamedlem:': ['Inger Hegstad Krüger',
#    'Siv Anne-Marie Øgren Lindstad',
#    'Tonje Pettersen',
#    'Martine Jonette Hoseth Myklebust',
#    'Lars Sokrates Anvil',
#    'Audun Zeiner',
#    'Mats Werner Larsen']},
#  '923884874': {'Daglig leder/ adm.direktør:': ['Gaute Ervik Bakke'],
#   'Styrets leder:': ['Lasse Carlsen Smedsvig'],
#   'Styremedlem:': ['Karl-Axel Hjorth Bauer']},
#  '821672872': {'Daglig leder/ adm.direktør:': ['Niko Menti'],
#   'Styrets leder:': ['Timothy Jon Homer']},
#  '922114870': {'Daglig leder/ adm.direktør:': ['Kardo Bradosty'],
#   'Styrets leder:': ['Kardo Bradosty']},
#  '988559202': {'Daglig leder/ adm.direktør:': ['Frederik Holger Mygind'],
#   'Styrets leder:': ['Adam Nederby Falbert']},
#  '914754437': {'Daglig leder/ adm.direktør:': ['Tarje Haakstad'],
#   'Styrets leder:': ['Tarje Haakstad']},
#  '912644324': {'Daglig leder/ adm.direktør:': ['Karl-Henning Fahlstrøm Svendsen'],
#   'Styrets leder:': ['Karl-Henning Fahlstrøm Svendsen'],
#   'Styremedlem:': ['Eddy Karen Egizarian', 'Morten Peter Usterud']},
#  '981477650': {'Daglig leder/ adm.direktør:': ['Kate Andersson']},
#  '913640888': {'Daglig leder/ adm.direktør:': ['Mobin Ajaib'],
#   'Styrets leder:': ['Mobin Ajaib']},
#  '948181150': {'Daglig leder/ adm.direktør:': ['Tarje Hellebust'],
#   'Styrets leder:': ['Lars Wenaas'],
#   'Styremedlem:': ['Trude Wenaas',
#    'Dilcia Eugenia De Olival Pereira Valenzuela',
#    'Hilje Stormo'],
#   'Varamedlem:': ['Stein Gunnar Slemdal', 'Tina Trinh Hong Nguyen Barkbu']},
#  '987801867': {'Innehaver:': ['Man Di Tran']},
#  '926572032': {'Kontaktperson:': ['Alexander Münster-Dahl'],
#   'Styrets leder:': ['Line Mari Haugland Münster-Dahl'],
#   'Nestleder:': ['Alexander Münster-Dahl']},
#  '921261004': {'Styrets leder:': ['Gurpreet Singh']},
#  '820811712': {'Kontaktperson:': ['Morten Hiemeyer'],
#   'Styrets leder:': ['Pål Georg Gundersen'],
#   'Styremedlem:': ['Morten Hiemeyer',
#    'Vegard Barhaugen Kjos',
#    'Ole Anders Engebretsen']},
#  '913169883': {'Daglig leder/ adm.direktør:': ['Kjetil Enger'],
#   'Styrets leder:': ['Eirik Bergh'],
#   'Styremedlem:': ['Anders Aasen', 'Birgir Thor Bieltvedt', 'Rolf Stavnem']},
#  '822899552': {'Daglig leder/ adm.direktør:': ['Hassan Al Shami'],
#   'Styrets leder:': ['Hassan Al Shami']},
#  '995748983': {'Daglig leder/ adm.direktør:': ['Esben Holmboe Bang'],
#   'Styrets leder:': ['Bjørn Tore Furset'],
#   'Styremedlem:': ['Esben Holmboe Bang']},
#  '928077888': {'Daglig leder/ adm.direktør:': ['Angela Patricia Quesada Borja'],
#   'Styrets leder:': ['Ivan Mares']},
#  '927703114': {'Daglig leder/ adm.direktør:': ['Son Lam Bui'],
#   'Styrets leder:': ['Son Lam Bui'],
#   'Nestleder:': ['Ngoc Thao Thi Bui']},
#  '946175986': {'Daglig leder/ adm.direktør:': ['Håvard Stokke Abrahamsen'],
#   'Styrets leder:': ['Bodil Kristine Høstmælingen'],
#   'Styremedlem:': ['Kristine Klaveness',
#    'Eva Sannum',
#    'Ingrid Haukvik-Jensen',
#    'Elisabeth Longva Berger',
#    'Jan Grønbech',
#    'Christian Johannes Lunde',
#    'Christian Stabell Eriksen',
#    'Lars Gurandsrud',
#    'Pål Schwartz Samuelsen']},
#  '821571162': {'Styrets leder:': ['Ahmet Arikan']},
#  '918837841': {'Daglig leder/ adm.direktør:': ['Tariq Aziz'],
#   'Styrets leder:': ['Tariq Aziz'],
#   'Styremedlem:': ['Mudassar Aziz']},
#  '924971290': {'Daglig leder/ adm.direktør:': ['Fredrik Ørjansen Aasgaard'],
#   'Styrets leder:': ['Fredrik Ørjansen Aasgaard'],
#   'Styremedlem:': ['Rune Hoddevik Dagsgard', 'Mads Bjerkek Aasgaard']},
#  '913484770': {'Kontaktperson:': ['Phuong Thi Phan'],
#   'Styrets leder:': ['Phuong Thi Phan']},
#  '912173275': {'Daglig leder/ adm.direktør:': ['Lulzim Ademi'],
#   'Styrets leder:': ['Lulzim Ademi'],
#   'Varamedlem:': ['Nakil Ademi']},
#  '823463812': {'Daglig leder/ adm.direktør:': ['Bente Løvberg'],
#   'Styrets leder:': ['Bente Løvberg']},
#  '920207030': {'Daglig leder/ adm.direktør:': ['Adnan Tasleem Chaudhary'],
#   'Styrets leder:': ['Adnan Tasleem Chaudhary'],
#   'Styremedlem:': ['Khurram Shehzad Ali']},
#  '916622929': {'Daglig leder/ adm.direktør:': ['Mehmet Duvarci',
#    'Celalettin Duvarci'],
#   'Styrets leder:': ['Mehmet Duvarci']},
#  '876217392': {'Daglig leder/ adm.direktør:': ['Qaiser Ali', 'Asad Ali'],
#   'Styrets leder:': ['Qaiser Ali'],
#   'Varamedlem:': ['Shafqat Raza']},
#  '915865488': {'Daglig leder/ adm.direktør:': ['Irene Larsen'],
#   'Styrets leder:': ['Stian Erling Syvertsen'],
#   'Styremedlem:': ['Geir Thomas Nordhaug', 'Ketil Fagervik', 'Eivind Pilskog'],
#   'Varamedlem:': ['David Bratlie']},
#  '926462059': {'Daglig leder/ adm.direktør:': ['Aleksander Solbakken Iversen'],
#   'Styrets leder:': ['James Ian Maxwell-Stewart']},
#  '996531937': {'Daglig leder/ adm.direktør:': ['Erik Nordbrenden'],
#   'Styrets leder:': ['Erik Nordbrenden'],
#   'Varamedlem:': ['Marie Helena Asp']},
#  '925883085': {'Styrets leder:': ['Kim André Kristensen'],
#   'Styremedlem:': ['Jens Fredrik Jensen', 'Markus Presttun Hindenes']},
#  '937087977': {'Daglig leder/ adm.direktør:': ['Jesper Lien'],
#   'Styrets leder:': ['Jesper Lien'],
#   'Styremedlem:': ['Monika Mellum',
#    'Nils Erik Bernhard Eriksson',
#    'Hege Ekelund Brandhaug'],
#   'Varamedlem:': ['Malin Grindvold Fossback']},
#  '927344874': {'Daglig leder/ adm.direktør:': ['Blerim Idrizi'],
#   'Styrets leder:': ['Blerim Idrizi']},
#  '927403897': {'Daglig leder/ adm.direktør:': ['Anneli Sande'],
#   'Styrets leder:': ['Anneli Sande']},
#  '824788162': {'Styrets leder:': ['Khodadad Nabizadeh']},
#  '992487046': {'Daglig leder/ adm.direktør:': ['Parinya Wongthongkham'],
#   'Innehaver:': ['Pinjukorn Søreng']},
# ...
#  '914366518': {'Daglig leder/ adm.direktør:': ['Line Myhrene Glende'],
#   'Styrets leder:': ['Andreas Glende'],
#   'Varamedlem:': ['Dag Christensen Myhrene']},
#  '920674682': {'Daglig leder/ adm.direktør:': ['Jeevarajah Sivasamboo'],
#   'Styrets leder:': ['Jeevarajah Sivasamboo']},
#  '997189493': {'Innehaver:': ['Zafer Ullah Khan']},
#  '916900678': {'Daglig leder/ adm.direktør:': ['Andreas Kristoffer Jacobsen'],
#   'Styrets leder:': ['Brian John Kovary'],
#   'Styremedlem:': ['Stian Bjervamoen']},
#  '899004612': {'Daglig leder/ adm.direktør:': ['Maiken Nilsen'],
#   'Styrets leder:': ['Maiken Nilsen']},
#  '917135495': {'Daglig leder/ adm.direktør:': ['Ha Trieu Nguyen Cao'],
#   'Styrets leder:': ['Ha Trieu Nguyen Cao'],
#   'Styremedlem:': ['Thi Hong Tuoi Van']},
#  '925854425': {'Daglig leder/ adm.direktør:': ['Sandra Helene Kristiansen'],
#   'Styrets leder:': ['Simen Vinge'],
#   'Styremedlem:': ['Ciscomar Mogueis', 'Sandra Helene Kristiansen']},
#  '928462730': {'Daglig leder/ adm.direktør:': ['Phillip Minh Tuan Tran'],
#   'Styrets leder:': ['Anders Holmefjord Lillevik'],
#   'Styremedlem:': ['Jack Grung Farsund']},
#  '813959852': {'Daglig leder/ adm.direktør:': ['Rizwan Ahmed'],
#   'Styrets leder:': ['Rizwan Ahmed']},
#  '993809128': {'Styrets leder:': ['Eigil Almenning']},
#  '918923055': {'Daglig leder/ adm.direktør:': ['Kine Therese Jøndal'],
#   'Styrets leder:': ['Fred Arne Bakken'],
#   'Styremedlem:': ['Kine Therese Jøndal', 'Björn Johan Dong-Soo Svensson']},
#  '924547936': {'Daglig leder/ adm.direktør:': ['Mamta Rani'],
#   'Styrets leder:': ['Mamta Rani']},
#  '919627379': {'Daglig leder/ adm.direktør:': ['Yngve Geir Thorstad'],
#   'Styrets leder:': ['Yngve Geir Thorstad'],
#   'Styremedlem:': ['Bandit Thipam-On']},
#  '917535701': {'Daglig leder/ adm.direktør:': ['Kacy Hien Vy'],
#   'Styrets leder:': ['Kacy Hien Vy']},
#  '918773991': {'Daglig leder/ adm.direktør:': ['Ronny Michael Gjøse'],
#   'Styrets leder:': ['Ronny Michael Gjøse']},
#  '913955986': {'Daglig leder/ adm.direktør:': ['Narmathaa Silvia Perinpanathan'],
#   'Styrets leder:': ['Narmathaa Silvia Perinpanathan'],
#   'Styremedlem:': ['Perinpanathan Sithamparanathan']},
#  '998833272': {'Daglig leder/ adm.direktør:': ['Chunle Wang'],
#   'Styrets leder:': ['Chunle Wang'],
#   'Varamedlem:': ['Rusong Gong']},
#  '885342272': {'Daglig leder/ adm.direktør:': ['Ole Jonny Eikefjord'],
#   'Styrets leder:': ['Mads Breder Koch'],
#   'Styremedlem:': ['Ole Jonny Eikefjord'],
#   'Varamedlem:': ['Torgeir Silseth']},
#  '919063173': {'Daglig leder/ adm.direktør:': ['Lukasz Albert Kmito'],
#   'Styrets leder:': ['Lukasz Albert Kmito']},
#  '923957596': {'Daglig leder/ adm.direktør:': ['Susanne Martens Låstad'],
#   'Styrets leder:': ['Sverre Helge Bøyum'],
#   'Styremedlem:': ['Susanne Martens Låstad']},
#  '983152260': {'Daglig leder/ adm.direktør:': ['Ingunn Svoren'],
#   'Styrets leder:': ['Steff Herbern'],
#   'Styremedlem:': ['Ingunn Svoren'],
#   'Varamedlem:': ['Wenche Kristin Svoren']},
#  '918001921': {'Daglig leder/ adm.direktør:': ['Fahmi Jonas El-Khatib'],
#   'Styrets leder:': ['Tor Christian Taalesen'],
#   'Styremedlem:': ['Fahmi Jonas El-Khatib', 'Alan Qahraman Salman']},
#  '925678902': {'Styrets leder:': ['Israr Ahmed']},
#  '926876120': {'Daglig leder/ adm.direktør:': ['Hoang Long Son Nguyen'],
#   'Styrets leder:': ['Mehmet Celik'],
#   'Styremedlem:': ['Anette Wittingsrud Celik', 'Vytautas Ulpys']},
#  '925283207': {'Styrets leder:': ['Anders Grimsø Moe'],
#   'Styremedlem:': ['Lydia Pedersen', 'Jon Wegner Petter Haaland']},
#  '922361754': {'Daglig leder/ adm.direktør:': ['Johnny Hoang Nguyen Pham'],
#   'Styrets leder:': ['Johnny Hoang Nguyen Pham']},
#  '896979922': {'Daglig leder/ adm.direktør:': ['Grunde Valldal'],
#   'Styrets leder:': ['Grunde Valldal'],
#   'Styremedlem:': ['Rebecca Ziburkute Valldal']},
#  '921630646': {'Daglig leder/ adm.direktør:': ['Björn Anders Johansson'],
#   'Styrets leder:': ['Björn Anders Johansson']},
#  '911592770': {'Daglig leder/ adm.direktør:': ['Caroline Qvist Sandell\n\t\t          \xa0\xa0\xa0\xa0\xa0\xa0Fratrådt\n                    '],
#   'Styrets leder:': ['Eva Karin Maria Flaig']},
#  '995878224': {'Daglig leder/ adm.direktør:': ['Christer Peter Niclas Wallin'],
#   'Styrets leder:': ['Per Gunnar Meland'],
#   'Styremedlem:': ['Tor Erik Hermansen'],
#   'Varamedlem:': ['Andreas Viestad']},
#  '990068321': {'Innehaver:': ['Kim Loan Rishovd']},
#  '999620175': {'Daglig leder/ adm.direktør:': ['Herdis Eiriksdottir'],
#   'Styrets leder:': ['Anna-Carin Elisabeth Svahn Ramsberg'],
#   'Styremedlem:': ['Erik Ramsberg', 'Trond Svellet', 'Ian Robert Skattum']},
#  '991368477': {'Daglig leder/ adm.direktør:': ['Pascal Frederic Dupuy'],
#   'Styrets leder:': ['Berit Myhre Dupuy'],
#   'Nestleder:': ['Pascal Frederic Dupuy'],
#   'Varamedlem:': ['Therese Myhre Dupuy', 'Aurora Myhre Dupuy']},
#  '915366155': {'Daglig leder/ adm.direktør:': ['Raja Isnan Iftikhar'],
#   'Styrets leder:': ['Raja Isnan Iftikhar'],
#   'Styremedlem:': ['Harpreet Singh']},
#  '916359667': {'Daglig leder/ adm.direktør:': ['Petter Ivar Haagaas'],
#   'Styrets leder:': ['Eivind Saga'],
#   'Styremedlem:': ['Petter Ivar Haagaas', 'Sverre Birger Flåskjer']},
#  '879996422': {'Daglig leder/ adm.direktør:': ['Abdul Ghafoor Khalid'],
#   'Styrets leder:': ['Abdul Ghafoor Khalid'],
#   'Varamedlem:': ['Imran Khalid']},
#  '922832293': {'Daglig leder/ adm.direktør:': ['Erlend Osland Simensen'],
#   'Styrets leder:': ['Andreas Doppelmayr'],
#   'Styremedlem:': ['Erlend Osland Simensen', 'Johan Brox']},
#  '918064877': {'Daglig leder/ adm.direktør:': ['Morten Peter Fjeld Mcroberts'],
#   'Styrets leder:': ['Morten Peter Fjeld Mcroberts']},
#  '988021490': {'Daglig leder/ adm.direktør:': ['Shi Er Yuan'],
#   'Styrets leder:': ['Shi Er Yuan'],
#   'Varamedlem:': ['Weijiang Gong']},
#  '990115001': {'Kontaktperson:': ['Ulf Bakke'],
#   'Styrets leder:': ['Ulf Bakke'],
#   'Styremedlem:': ['Thomas Wold'],
#   'Varamedlem:': ['Niels Christian Ditleff']},
#  '816672392': {'Daglig leder/ adm.direktør:': ['Tham Thi Van'],
#   'Styrets leder:': ['Tham Thi Van'],
#   'Styremedlem:': ['Sinnappu Thambirajah']},
#  '911836459': {'Daglig leder/ adm.direktør:': ['Dong Van Hoong'],
#   'Styrets leder:': ['Celine Lien Hoong'],
#   'Varamedlem:': ['Dong Van Hoong']},
#  '913376560': {'Daglig leder/ adm.direktør:': ['Rolf Fredrik Ekelund'],
#   'Styrets leder:': ['Rolf Fredrik Ekelund'],
#   'Styremedlem:': ['Audun Romstad Stavne']},
#  '926119354': {'Daglig leder/ adm.direktør:': ['Marit Soldal'],
#   'Styrets leder:': ['Arnt Olaf Andersen'],
#   'Styremedlem:': ['Runar Skjerven Eggesvik', 'Eyvind Brox']},
#  '919146133': {'Kontaktperson:': ['Morten Gunnar Estensmo'],
#   'Styrets leder:': ['Diana Riz Estensmo'],
#   'Styremedlem:': ['Morten Gunnar Estensmo']},
#  '928662896': {'Daglig leder/ adm.direktør:': ['George Soete'],
#   'Styrets leder:': ['George Soete']},
#  '921092768': {'Daglig leder/ adm.direktør:': ['Annie Emelie Viktoria Sjögren'],
#   'Styrets leder:': ['Anders Braathen'],
#   'Styremedlem:': ['Tom Victor Gausdal', 'Even Ramsvik']},
#  '922695253': {'Daglig leder/ adm.direktør:': ['Christina Smeby'],
#   'Styrets leder:': ['Heidi Lind Hopstock'],
#   'Styremedlem:': ['Hans Reinhardt Trosby',
#    'Christina Smeby',
#    'Anette Nauf',
#    'Batoul Hamza']},
#  '925424153': {'Daglig leder/ adm.direktør:': ['Wafa Haddoumi'],
#   'Styrets leder:': ['Wafa Haddoumi']},
#  '995311895': {'Daglig leder/ adm.direktør:': ['Bo Vivike'],
#   'Styrets leder:': ['Bo Vivike'],
#   'Styremedlem:': ['Sebastian Myhre', 'Are Sandved Lunde'],
#   'Varamedlem:': ['Anders Erik Nilsson']},
#  '911577933': {'Daglig leder/ adm.direktør:': ['Bich Ngoc Thi Pham'],
#   'Styrets leder:': ['Bich Ngoc Thi Pham'],
#   'Varamedlem:': ['Hoa Duc Luu']},
#  '996469190': {'Daglig leder/ adm.direktør:': ['Jannike Maria Vouti'],
#   'Styrets leder:': ['Peer Christer Svedbergh']},
#  '917808643': {'Daglig leder/ adm.direktør:': ['Karl Anders Lakso'],
#   'Styrets leder:': ['Max Richard Melker Bergfors'],
#   'Styremedlem:': ['Dan Robert Christoffer Bergfors', 'Sören Gunnar Nismalm'],
#   'Varamedlem:': ['Karl Anders Lakso']},
#  '926109472': {'Daglig leder/ adm.direktør:': ['Deepak Mahat'],
#   'Styrets leder:': ['Deepak Mahat']},
#  '917506817': {'Daglig leder/ adm.direktør:': ['Julia Løvgren Holmboe\n\t\t          \xa0\xa0\xa0\xa0\xa0\xa0Fratrådt\n                    '],
#   'Styrets leder:': ['Linda Natalia Tunheim']},
#  '928025799': {'Styrets leder:': ['Alexander Bølla']},
#  '922809623': {'Daglig leder/ adm.direktør:': ['Sarah Hansen Tandberg'],
#   'Styrets leder:': ['Per Magnus Falnes']},
#  '982288053': {'Daglig leder/ adm.direktør:': ['Ivar Bowitz'],
#   'Styrets leder:': ['Robert William Kallhovd Thoresen']},
#  '929609220': {'Daglig leder/ adm.direktør:': ['Prakash Baral'],
#   'Styrets leder:': ['Prakash Baral'],
#   'Styremedlem:': ['Tikaram Acharya']},
#  '916787790': {'Daglig leder/ adm.direktør:': ['Karl-Henning Fahlstrøm Svendsen'],
#   'Styrets leder:': ['Karl-Henning Fahlstrøm Svendsen'],
#   'Styremedlem:': ['Morten Peter Usterud', 'Eddy Karen Egizarian']},
#  '999096298': {'Kontaktperson:': ['Even Bernhard Bergstrøm Hegbom'],
#   'Styrets leder:': ['Even Bernhard Bergstrøm Hegbom'],
#   'Styremedlem:': ['Jan Ivar Brataas'],
#   'Varamedlem:': ['Kjellaug Brenden Hegbom']},
#  '913939964': {'Daglig leder/ adm.direktør:': ['Karl-Henning Fahlstrøm Svendsen'],
#   'Styrets leder:': ['Eddy Karen Egizarian'],
#   'Styremedlem:': ['Karl-Henning Fahlstrøm Svendsen', 'Morten Peter Usterud']},
#  '917321531': {'Daglig leder/ adm.direktør:': ['Philip Christopher Bernard Skopakow'],
#   'Styrets leder:': ['Lars Bjørn Larsen'],
#   'Styremedlem:': ['Fredrik Syversen', 'Einar Kleppe Holthe']},
#  '922920141': {'Daglig leder/ adm.direktør:': ['Siri Helen Winther'],
#   'Styrets leder:': ['Jan Petter Lundeby'],
#   'Styremedlem:': ['Svein Erik Dahl', 'Siri Helen Winther', 'Vegard Kjuus']},
#  '993461776': {'Daglig leder/ adm.direktør:': ['Hong Lin'],
#   'Styrets leder:': ['He Ping Chen'],
#   'Varamedlem:': ['Hong Lin']},
#  '923846883': {'Daglig leder/ adm.direktør:': ['Serdal Gelir'],
#   'Styrets leder:': ['Noelia Garcia-Rojo Casado']},
#  '992820829': {'Daglig leder/ adm.direktør:': ['Gary John Anderton'],
#   'Styrets leder:': ['Linda Bjercke'],
#   'Varamedlem:': ['Gary John Anderton']},
#  '926330187': {'Daglig leder/ adm.direktør:': ['Mohammed Ibrahim Zaghmout'],
#   'Styrets leder:': ['Mohammed Ibrahim Zaghmout']},
#  '912344665': {'Daglig leder/ adm.direktør:': ['Lise Marie Morfjord'],
#   'Styrets leder:': ['Lise Marie Morfjord']},
#  '911578476': {'Kontaktperson:': ['Rodrigo Alejandro Lavin Belda'],
#   'Styrets leder:': ['Erik Tronbøl'],
#   'Styremedlem:': ['Jan Ivar Sørensen', 'Rodrigo Alejandro Lavin Belda']},
#  '994901079': {'Daglig leder/ adm.direktør:': ['Emil Hesselberg'],
#   'Styrets leder:': ['Michael Andre Henriksen'],
#   'Varamedlem:': ['Christine Bergan']},
#  '998656206': {'Daglig leder/ adm.direktør:': ['Rune Sandvik'],
#   'Styrets leder:': ['Espen Hoff'],
#   'Styremedlem:': ['Kim Andre Klæbo']},
#  '923821619': {'Daglig leder/ adm.direktør:': ['Vimalan Sooriamoorthy'],
#   'Styrets leder:': ['Vimalan Sooriamoorthy']},
#  '997831365': {'Daglig leder/ adm.direktør:': ['Tore Kristian Tofte'],
#   'Styrets leder:': ['Tharald Stray Laastad'],
#   'Styremedlem:': ['Tore Kristian Tofte']},
#  '920777414': {'Daglig leder/ adm.direktør:': ['Lasse Juul Horn'],
#   'Styrets leder:': ['Sandra Tolderlund Marquardsen'],
#   'Styremedlem:': ['Lasse Juul Horn']},
#  '922592616': {'Daglig leder/ adm.direktør:': ['Riaz Ahmad Bhatti'],
#   'Styrets leder:': ['Riaz Ahmad Bhatti']},
#  '923304665': {'Daglig leder/ adm.direktør:': ['Rolf Fredrik Ekelund'],
#   'Styrets leder:': ['Rolf Fredrik Ekelund'],
#   'Styremedlem:': ['Audun Romstad Stavne']},
#  '976940768': {'Innehaver:': ['Ghazala Shaheen']},
#  '823832982': {'Daglig leder/ adm.direktør:': ['Stian Bua Hellestad'],
#   'Styrets leder:': ['Stian Bua Hellestad'],
#   'Styremedlem:': ['Silje Bua Hellestad']},
#  '914051592': {'Daglig leder/ adm.direktør:': ['Camilla Bredesen'],
#   'Styrets leder:': ['Petter Sandberg'],
#   'Styremedlem:': ['Bjørn Olvik',
#    'Aino Kristin Lindal Olaisen',
#    'Odd Lorentz Strøm',
#    'Thea Cecilie Sandberg',
#    'Marius Peder Sandberg']},
#  '925891525': {'Daglig leder/ adm.direktør:': ['Lisa Hanh Ngoc Nguyen'],
#   'Styrets leder:': ['Lisa Hanh Ngoc Nguyen']},
#  '874691372': {'Daglig leder/ adm.direktør:': ['Sara Mikaela Jensen-Skelton'],
#   'Styrets leder:': ['Torgeir Silseth'],
#   'Styremedlem:': ['Espen Viig Syversen', 'Trine Lise Marsdal']},
#  '983238874': {'Daglig leder/ adm.direktør:': ['Stein Arve Bernes'],
#   'Styrets leder:': ['Richard Müller'],
#   'Varamedlem:': ['Morten Ahlbom']},
#  '814446832': {'Daglig leder/ adm.direktør:': ['Samir Sharma'],
#   'Styrets leder:': ['Samir Sharma']},
#  '817403352': {'Daglig leder/ adm.direktør:': ['Tiril Lunde Refsum'],
#   'Styrets leder:': ['Tiril Lunde Refsum'],
#   'Styremedlem:': ['Stein Guttorm Lunde']},
#  '920874444': {'Daglig leder/ adm.direktør:': ['Komal Preet Khehra'],
#   'Styrets leder:': ['Komal Preet Khehra'],
#   'Styremedlem:': ['Jaideep Singh Khehra']},
#  '918752773': {'Daglig leder/ adm.direktør:': ['Erdal Vural'],
#   'Styrets leder:': ['Erdal Vural']},
#  '925747238': {'Daglig leder/ adm.direktør:': ['Henrik Orre'],
#   'Styrets leder:': ['Per Christensen'],
#   'Styremedlem:': ['Aaron Ashley Apew',
#    'Are Strøm',
#    'Alexandra Katharina Diem',
#    'Henrik Orre']},
#  '921668198': {'Daglig leder/ adm.direktør:': ['Jarle Moen'],
#   'Styrets leder:': ['Torgeir Silseth'],
#   'Styremedlem:': ['Mona Amalie Aarebrot Tangen',
#    'Petter Anker Stordalen',
#    'Mads Breder Koch',
#    'Jahn Christopher Utne',
#    'Gunnar Gehrken Bøyum']},
#  '913269276': {'Kontaktperson:': ['Sindy Tran'],
#   'Styrets leder:': ['Sindy Tran']},
#  '814861082': {'Daglig leder/ adm.direktør:': ['Håvard Nelvik'],
#   'Styrets leder:': ['Håvard Nelvik']},
#  '991642676': {'Daglig leder/ adm.direktør:': ['Jennie Elin Maria Lager Kihlman'],
#   'Styrets leder:': ['Bjørn Tore Furset']},
#  '922257299': {'Daglig leder/ adm.direktør:': ['Lars Johan Bernvald'],
#   'Styrets leder:': ['Mikael Sören Åkerlund']},
#  '925379794': {'Styrets leder:': ['Olaf Masterman Loly'],
#   'Styremedlem:': ['Karl-Henning Fahlstrøm Svendsen']},
#  '910856286': {'Daglig leder/ adm.direktør:': ['Magnus Brun'],
#   'Styrets leder:': ['Håvar Wiik'],
#   'Styremedlem:': ['Axel Brun', 'Trygve Olav Mathisen']},
#  '915708951': {'Daglig leder/ adm.direktør:': ['Bowie Kiat'],
#   'Styrets leder:': ['Yat Fai Cheng'],
#   'Styremedlem:': ['Yat Shing Cheng', 'Yat Yiu Cheng']},
#  '915255159': {'Daglig leder/ adm.direktør:': ['Huan Quoc Nguyen'],
#   'Styrets leder:': ['Kim Ngan Thi Nguyen']},
#  '997470907': {'Styrets leder:': ['Tuyen Bang Thi Tran']},
#  '985026270': {'Daglig leder/ adm.direktør:': ['Jan Einar Skaug'],
#   'Styrets leder:': ['Jan Einar Skaug'],
#   'Varamedlem:': ['Vidar Valentin Nordanger']},
#  '920781659': {'Daglig leder/ adm.direktør:': ['Dong Van Hoong'],
#   'Styrets leder:': ['Celine Lien Hoong'],
#   'Varamedlem:': ['Dong Van Hoong', 'Emma Hoong']},
#  '919368861': {'Daglig leder/ adm.direktør:': ['Raza Habib'],
#   'Styrets leder:': ['Raza Habib'],
#   'Styremedlem:': ['Mohammad Faisel\n\t\t        \xa0\xa0\xa0\xa0\xa0\xa0Fratrådt\n\t\t      ']},
#  '927664798': {'Styrets leder:': ['Dheeraj Singh Arora'],
#   'Styremedlem:': ['Shamir Johan Parmar']},
#  '829452642': {'Daglig leder/ adm.direktør:': ['Loay Rahim Jasim Al Husseini'],
#   'Styrets leder:': ['Loay Rahim Jasim Al Husseini']},
#  '917429790': {'Daglig leder/ adm.direktør:': ['Montazar Majeed Abdelsaheb Al-Ohele'],
#   'Styrets leder:': ['Montazar Majeed Abdelsaheb Al-Ohele']},
#  '815977882': {'Daglig leder/ adm.direktør:': ['Taiba Iram Mushtaq'],
#   'Styrets leder:': ['Saima Noreen'],
#   'Styremedlem:': ['Taiba Iram Mushtaq', 'Ashiq Hussain', 'Qamar Abbas']},
#  '915357679': {'Innehaver:': ['Baljinder Kaur']},
#  '920195253': {'Daglig leder/ adm.direktør:': ['Thi Ngoc Huong Duong'],
#   'Innehaver:': ['Thi Ngoc Huong Duong']},
#  '924009519': {'Daglig leder/ adm.direktør:': ['Vy Le'],
#   'Styrets leder:': ['Vy Le']},
#  '924709537': {'Innehaver:': ['Faten Ahmed']},
#  '923400435': {'Daglig leder/ adm.direktør:': ['Cam Hang Nguyen'],
#   'Styrets leder:': ['Cam Hang Nguyen']},
#  ...}

# %% [markdown]
# ### Filtering out all the people. With the assumption that people with the same name are the same people.

# %%
all_people = []

for orgnumber, company in data_structure.items():
    
    for role, person_list in company.items():

        for person in person_list:
            all_people.append(person)

# %%
# Removing the excess characters for names.
clean_list_of_people = []
for person in all_people:
    name = ""
    for character in person:
        if character in ["\n"]:
            break
        else:
            name = name + character
    clean_list_of_people.append(name)

# %%
unique_names = list(set(clean_list_of_people))

# %%
print(f"Complete number of names: {len(clean_list_of_people)}")
print(f"Number of unique names: {len(unique_names)}")
# Out:
# Complete number of names: 3047
# Number of unique names: 1853

# %% [markdown]
# A big chunk of the loss comes from people having multiple roles within the same company.

# %% [markdown]
# ### Creating the people dataframe:

# %%
# Adding the names to the dataframe and adding a person_id based on index.
df_people = pd.DataFrame(unique_names, columns =['navn'])
df_people["person_id"] = df_people.index
df_people
# Out:
#                               navn  person_id
# 0          Marisa Rafaella Valente          0
# 1     Victor Joseph Demison Lionel          1
# 2                      Gaute Houge          2
# 3            Berivan Hamide Ciftci          3
# 4            Jeevarajah Sivasamboo          4
# ...                            ...        ...
# 1848                   Rudolf Reim       1848
# 1849                 Magnus Tvenge       1849
# 1850                Jan Abrahamsen       1850
# 1851               Shadi Haj Yahia       1851
# 1852           Veronica Løset Bono       1852
#
# [1853 rows x 2 columns]

# %% [markdown]
# ### Creating the Junction tabels

# %%
org_num = [[],[],[],[],[],[],[]]
name = [[],[],[],[],[],[],[]]

for orgnumber, company in data_structure.items():
    for role, person_list in company.items():

        for num in range(len(list_of_search_parameters)):
            if role == list_of_search_parameters[num]:
                
                for person in person_list:
                    org_num[num].append(orgnumber)
                    name[num].append(person)

# %%
list_of_search_parameters
# Out:
# ['Daglig leder/ adm.direktør:',
#  'Innehaver:',
#  'Kontaktperson:',
#  'Styrets leder:',
#  'Nestleder:',
#  'Styremedlem:',
#  'Varamedlem:']

# %% [markdown]
# #### Convert into dataframes

# %%
def uppdata_current_status(name):
    """Returns True if the name contains the string "Fratrådt".

    Args:
        name (string): string as part of a dataframe column.    

    Returns:
        bool: True or False based on the name.
    """
    if re.search("Fratrådt", name):
        return True
    else:
        return False

# %%
def remove_excess_in_name(name):
    """Removes the excess string "Fratrådt" from the name.

    Args:
        name (string): name of person.

    Returns:
        string: name without the "Fratrådt" string
    """
    if re.search("Fratrådt", name):
        return_name = ""
        for char in name:
            if char in ["\n"]:
                break
            else:
                return_name = return_name + char
        return return_name
    else:
        return name

# %%
def name_to_person_id(name):
    """Requires the df_people dataframe, gets the id of a person based on the name.

    Args:
        name (str): name of a person in string format, case sensetive.

    Returns:
        int: person id from the df_people dataframe.
    """
    return int(df_people.loc[df_people['navn']==name]['person_id'])

# %%
list_of_search_parameters
# Out:
# ['Daglig leder/ adm.direktør:',
#  'Innehaver:',
#  'Kontaktperson:',
#  'Styrets leder:',
#  'Nestleder:',
#  'Styremedlem:',
#  'Varamedlem:']

# %%
list_of_role_dfs = []
for num in range(len(list_of_search_parameters)):
    list_of_role_dfs.append(pd.DataFrame({  'organisasjonsnummer': org_num[num],
                                            'person_id': name[num]}))
    list_of_role_dfs[num]['Fratrådt'] = list_of_role_dfs[num]['person_id'].map(uppdata_current_status)
    list_of_role_dfs[num]['person_id'] = list_of_role_dfs[num]['person_id'].map(remove_excess_in_name)
    list_of_role_dfs[num]['person_id'] = list_of_role_dfs[num]['person_id'].map(name_to_person_id)

# %%
df_people.head(2)
# Out:
#                            navn  person_id
# 0       Marisa Rafaella Valente          0
# 1  Victor Joseph Demison Lionel          1

# %%
df_daglig_leder = list_of_role_dfs[0]
df_daglig_leder.head(2)
# Out:
#   organisasjonsnummer  person_id  Fratrådt
# 0           927526891        341     False
# 1           926646419        799     False

# %%
df_innehaver = list_of_role_dfs[1]
df_innehaver.head(2)
# Out:
#   organisasjonsnummer  person_id  Fratrådt
# 0           893105182        311     False
# 1           986113258        190     False

# %%
df_kontaktperson = list_of_role_dfs[2]
df_kontaktperson.head(2)
# Out:
#   organisasjonsnummer  person_id  Fratrådt
# 0           980147622       1824     False
# 1           991098577        552     False

# %%
df_styrets_leder = list_of_role_dfs[3]
df_styrets_leder.head(2)
# Out:
#   organisasjonsnummer  person_id  Fratrådt
# 0           927526891        341     False
# 1           926646419        969     False

# %%
df_nestleder = list_of_role_dfs[4]
df_nestleder.head(2)
# Out:
#   organisasjonsnummer  person_id  Fratrådt
# 0           930727334       1319     False
# 1           914192900        773     False

# %%
df_styremedlem = list_of_role_dfs[5]
df_styremedlem.head(2)
# Out:
#   organisasjonsnummer  person_id  Fratrådt
# 0           927526891       1728     False
# 1           926646419        972     False

# %%
df_varamedlem = list_of_role_dfs[6]
df_varamedlem.head(2)
# Out:
#   organisasjonsnummer  person_id  Fratrådt
# 0           814599892        830     False
# 1           958596936        601     False

# %%
# Function that stores the raw data as a pickle file.
# Gets the parent directory location enabeling storing the 
# data directly to the desired folder.

def pickler(file, file_name):	
    parent = path.abspath(path.join("brønnøysund_roller_scraped_extractor.ipynb", "../../.."))
    path = "/Data/Extracted/"
    with open(f'{parent + path + file_name}.obj', 'wb') as f:
        pickle.dump(file, f)

# %%
j = "junction_table"
pickler(df_people, "df_people")
pickler(df_daglig_leder, f"df_daglig_leder{j}")
pickler(df_innehaver, f"df_innehaver{j}")
pickler(df_kontaktperson, f"df_kontaktperson{j}")
pickler(df_nestleder, f"df_nestleder{j}")
pickler(df_styremedlem, f"df_styremedlem{j}")
pickler(df_styrets_leder, f"df_styrets_leder{j}")
pickler(df_varamedlem, f"df_varamedlem{j}")
